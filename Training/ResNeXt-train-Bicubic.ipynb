# %% [markdown]
# # Training ResNeXt with Bicubic Scaled Up Images

# %% [markdown]
# This Notebook will go through the process of training the ResNeXt model with an architecture that is optimized for the Cifar Dataset (as specified in [1] https://arxiv.org/pdf/1611.05431.pdf). We will artifically scale-up the input image by a factor of x2 or x4 and feed it into enlarged first two layers of the model.

# %%
import os
import sys
import json
import shutil
import torch
import torch.nn.functional as F
import torchvision.datasets as dset
import torchvision.transforms as transforms
import time
from PIL import Image

# %%
sys.path.append("..") # Note, this line is needed only since this notebook is being run from inside 'bharat' directory
                      # If you run this notebook in the same folder as the the 'models-py-code' directory, remove this line
from pymodels.resnext_scaled import ScaledCifarResNeXt # This is where we actually refer to the model we wish to train

# %% [markdown]
# ## Set all required parameters
# Remember to change the `session_id` for each new model you wish to train or if you change of the other parameters

# %%
args={}

args['model_name'] = 'resnext-bicubic'

# Input Data Parameters
args['data_path'] = '/datasets/ee285s-public/'
args['dataset'] = 'cifar100' # The other option is 'cifar10'

# Scaling Parameters
args['scale_factor'] = 2

# Optimization options
args['epochs'] = 50
args['start_epoch'] = 0 # Change only if necessary. Used for resuming sessions
args['batch_size'] = 96
args['learning_rate'] = 0.1
args['momentum'] = 0.9 # Momentum
args['decay'] = 0.0005 # Weight decay (L2 penalty)
args['test_bs'] = 32 # Test Batch Size
args['schedule'] = [35, 45] # Decrease learning rate at these epochs
args['gamma'] = 0.1 # LR is multiplied by gamma on schedule.

# Checkpoints and Session Parameters
args['save_dir'] = './' # Folder to save checkpoint file and best model file
args['load'] = 'resnext-bicubic-x2-0-checkpoint.pth' # Path to load Checkpoint file 
args['session_id'] = '0' # Remember to change the session id for each new model you train

# Architecture
args['depth'] = 29 # Model depth
args['cardinality'] = 8 # Model cardinality (group)
args['base_width'] = 64 # Number of channels in each group
args['widen_factor'] = 4 # Widen factor. 4 -> 64, 8 -> 128, ...

# Acceleration
args['ngpu'] = 1 # 0 = CPU
args['prefetch'] = 4 # Pre-fetching threads

# i/o
args['log_dir'] = './log/' # Log folder

# Create a Dictionary to describe the state every epoch
epoch_state = {'args' : args}

# %% [markdown]
# ### Initialize Logging

# %%
if not os.path.isdir(args['log_dir']):
        os.makedirs(args['log_dir'])

log_file_name = '{}-x{}-{}-log.txt'.format(args['model_name'],
                                           args['scale_factor'],
                                           args['session_id'])
if args['load'] == '':
    log = open(os.path.join(args['log_dir'], log_file_name), 'w')
else:
    log = open(os.path.join(args['log_dir'], log_file_name), 'a')    
print('Exisiting log {} loaded.'.format(log_file_name))
# Out:
# Exisiting log resnext-bicubic-x2-0-log.txt loaded.

# %% [markdown]
# ### Setup the Input Data

# %%
mean = [x / 255 for x in [125.3, 123.0, 113.9]]
std = [x / 255 for x in [63.0, 62.1, 66.7]]

train_transform = transforms.Compose(
    [transforms.Resize((64,64), interpolation = Image.BICUBIC),
     transforms.RandomHorizontalFlip(),
     transforms.RandomCrop(32, padding=4),
     transforms.ToTensor(),
     transforms.Normalize(mean, std)])

test_transform = transforms.Compose(
    [transforms.Resize((64,64), interpolation = Image.BICUBIC),
     transforms.ToTensor(),
     transforms.Normalize(mean, std)])

if args['dataset'] == 'cifar10':
    train_data = dset.CIFAR10(args['data_path'], train=True, transform=train_transform, download=False)
    test_data = dset.CIFAR10(args['data_path'], train=False, transform=test_transform, download=False)
    nlabels = 10
else:
    train_data = dset.CIFAR100(args['data_path'], train=True, transform=train_transform, download=False)
    test_data = dset.CIFAR100(args['data_path'], train=False, transform=test_transform, download=False)
    nlabels = 100

train_loader = torch.utils.data.DataLoader(train_data, batch_size=args['batch_size'], shuffle=True,
                                                                       num_workers=args['prefetch'], pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=args['test_bs'], shuffle=False,
                                                                     num_workers=args['prefetch'], pin_memory=True)

# %% [markdown]
# ### Setup the Model, Criterion, and Optimizer

# %%
resnext_model = ScaledCifarResNeXt(args['cardinality'], args['depth'], nlabels, args['base_width'], args['widen_factor'], args['scale_factor'])
print(resnext_model)
if args['ngpu'] > 1:
    resnext_model = torch.nn.DataParallel(resnext_model, device_ids=list(range(args['ngpu'])))

if args['ngpu'] > 0:
    resnext_model.cuda()

optimizer = torch.optim.SGD(resnext_model.parameters(), args['learning_rate'], momentum=args['momentum'],
                            weight_decay=args['decay'], nesterov=True)
# Out:
# ScaledCifarResNeXt(
#   (conv_1_3x3): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (stage_1): Sequential(
#     (stage_1_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (shortcut_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_1_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_1_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (stage_2): Sequential(
#     (stage_2_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (shortcut_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_2_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_2_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (stage_3): Sequential(
#     (stage_3_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (shortcut_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_3_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_3_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (classifier): Linear(in_features=1024, out_features=100, bias=True)
# )

# %% [markdown]
# ### Setup the Train and Test Functions

# %%
def train(epoch):
    resnext_model.train()
    loss_avg = 0.0
    t0 = time.time()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = torch.autograd.Variable(data.cuda()), torch.autograd.Variable(target.cuda())

        # forward
        output = resnext_model(data)

        # backward
        optimizer.zero_grad()
        t0 = time.time()
        loss = F.cross_entropy(output, target)
        t1 = time.time()
        loss.backward()
        optimizer.step()

        # exponential moving average
        loss_avg = loss_avg * 0.2 + float(loss) * 0.8

        print("===> Epoch[{}]({}/{}): Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, batch_idx, len(train_loader), loss.data[0], (t1 - t0)))

    epoch_state['train_loss'] = loss_avg
    t1 = time.time()
    print("===> Epoch {} Complete: Avg. Loss: {:.4f} | Time: {:.4f}".format(epoch, loss_avg, (t1-t0)))

# test function (forward only)
def test():
    resnext_model.eval()
    loss_avg = 0.0
    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        data, target = torch.autograd.Variable(data.cuda()), torch.autograd.Variable(target.cuda())

        # forward
        output = resnext_model(data)
        loss = F.cross_entropy(output, target)

        # accuracy
        pred = output.data.max(1)[1]
        correct += float(pred.eq(target.data).sum())

        # test loss average
        loss_avg += float(loss)

    epoch_state['test_loss'] = loss_avg / len(test_loader)
    epoch_state['test_accuracy'] = correct / len(test_loader.dataset)

# %% [markdown]
# ### Define a function to save a checkpoint

# %%
def save_checkpoint(state, is_best, filename='{}-x{}-{}-checkpoint.pth'.format(args['model_name'],
                                                                               args['scale_factor'],
                                                                               args['session_id'])):
    filepath = os.path.join(args['save_dir'], filename)
    torch.save(state, filepath)
    if is_best:
        bestfilepath = os.path.join(args['save_dir'], 'model-best-resnext-{}.pth'.format(args['session_id']))
        shutil.copyfile(filepath, bestfilepath)

# %% [markdown]
# ### Load and Resume from checkpoint (if set)

# %%
if not args['load'] == '':
    if os.path.isfile(args['load']):
        print("=> Loading Checkpoint '{}'".format(args['load']))
        checkpoint = torch.load(args['load'])
        args['start_epoch'] = checkpoint['epoch'] + 1
        args['learning_rate'] = checkpoint['learning_rate']
        resnext_model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("=> Loaded checkpoint '{}' (epoch {})"
              .format(args['load'], checkpoint['epoch']))
    else:
        print("=> No checkpoint found at '{}'".format(args['load']))
# Out:
# => No checkpoint found at 'resnext-bicubic-x2-0-checkpoint.pth'

# %% [markdown]
# ### Main Loop

# %%
best_accuracy = 0.0

for epoch in range(args['start_epoch'], args['epochs']):
    if epoch in args['schedule']:
        args['learning_rate'] *= args['gamma']
        for param_group in optimizer.param_groups:
            param_group['lr'] = args['learning_rate']

    epoch_state['epoch'] = epoch
    train(epoch)
    test()
    if epoch_state['test_accuracy'] > best_accuracy:
        best_accuracy = epoch_state['test_accuracy']
        isbest = True
    
    save_checkpoint({
        'epoch' : epoch,
        'learning_rate' : args['learning_rate'],
        'state_dict' : resnext_model.state_dict(),
        'optimizer' : optimizer.state_dict()
    }, isbest)
    
    log.write('%s\n' % json.dumps(epoch_state))
    log.flush()
    #print(epoch_state)
    print("[Epoch {}] Best accuracy: {:.4f}".format(epoch, best_accuracy))

log.close()
# Out:
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](0/521): Loss: 5.7824 || Timer: 0.0008 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](1/521): Loss: 9.0215 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](2/521): Loss: 8.9558 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](3/521): Loss: 10.5652 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](4/521): Loss: 9.0680 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](5/521): Loss: 10.6633 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](6/521): Loss: 10.4189 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](7/521): Loss: 10.1486 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](8/521): Loss: 8.4597 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](9/521): Loss: 7.8169 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](10/521): Loss: 8.1554 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](11/521): Loss: 7.6824 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](12/521): Loss: 6.3571 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](13/521): Loss: 6.5295 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](14/521): Loss: 7.0682 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](15/521): Loss: 8.0164 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](16/521): Loss: 8.6623 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](17/521): Loss: 6.2048 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](18/521): Loss: 6.5787 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](19/521): Loss: 6.8814 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](20/521): Loss: 11.5035 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](21/521): Loss: 7.1470 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](22/521): Loss: 11.6812 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](23/521): Loss: 16.0575 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](24/521): Loss: 7.2613 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](25/521): Loss: 6.0424 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](26/521): Loss: 5.7040 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](27/521): Loss: 7.2492 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](28/521): Loss: 6.2026 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](29/521): Loss: 4.7564 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](30/521): Loss: 5.6209 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](31/521): Loss: 5.1964 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](32/521): Loss: 5.4289 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](33/521): Loss: 5.0407 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](34/521): Loss: 5.3886 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](35/521): Loss: 4.8517 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](36/521): Loss: 5.1624 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](37/521): Loss: 5.1997 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](38/521): Loss: 4.8032 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](39/521): Loss: 4.8889 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](40/521): Loss: 4.8225 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](41/521): Loss: 4.6509 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](42/521): Loss: 8.9427 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](43/521): Loss: 4.8484 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](44/521): Loss: 5.2228 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](45/521): Loss: 4.7252 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](46/521): Loss: 4.8272 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](47/521): Loss: 4.7732 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](48/521): Loss: 4.6588 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0
|| Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](480/521): Loss: 4.3206 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](481/521): Loss: 4.3465 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](482/521): Loss: 4.1818 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](483/521): Loss: 4.2988 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](484/521): Loss: 4.2874 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](485/521): Loss: 4.2662 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](486/521): Loss: 4.2411 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](487/521): Loss: 4.2748 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](488/521): Loss: 4.0829 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](489/521): Loss: 4.1444 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](490/521): Loss: 4.3090 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](491/521): Loss: 4.0641 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](492/521): Loss: 4.1931 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](493/521): Loss: 4.2131 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](494/521): Loss: 4.0581 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](495/521): Loss: 4.1820 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](496/521): Loss: 4.2248 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](497/521): Loss: 4.0367 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](498/521): Loss: 4.1336 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](499/521): Loss: 4.1035 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](500/521): Loss: 4.2190 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](501/521): Loss: 4.1574 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](502/521): Loss: 4.1187 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](503/521): Loss: 4.2293 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](504/521): Loss: 4.2547 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](505/521): Loss: 4.2994 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](506/521): Loss: 4.2908 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](507/521): Loss: 4.0760 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](508/521): Loss: 4.1225 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](509/521): Loss: 4.2273 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](510/521): Loss: 4.1307 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](511/521): Loss: 4.2880 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](512/521): Loss: 4.2935 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](513/521): Loss: 4.3116 || Timer: 0.0003 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](514/521): Loss: 4.2640 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](515/521): Loss: 4.1689 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](516/521): Loss: 4.0827 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](517/521): Loss: 4.1462 || Timer: 0.0002 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](518/521): Loss: 4.2398 || Timer: 0.0004 sec.
# torch.Size([96, 1024, 8, 8])
# torch.Size([96, 1024, 1, 1])
# torch.Size([96, 1024])
# torch.Size([96, 100])
# ===> Epoch[0](519/521): Loss: 4.0855 || Timer: 0.0004 sec.
# torch.Size([80, 1024, 8, 8])
# torch.Size([80, 1024, 1, 1])
# torch.Size([80, 1024])
# torch.Size([80, 100])
# ===> Epoch[0](520/521): Loss: 4.2593 || Timer: 0.0004 sec.
# ===> Epoch 0 Complete: Avg. Loss: 4.2299 | Time: 0.3829
# torch.Size([32, 1024, 16, 16])
# torch.Size([32, 1024, 5, 5])
# torch.Size([800, 1024])
# torch.Size([800, 100])
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-10-f07035ddfe0c> in <module>()
#       9     epoch_state['epoch'] = epoch
#      10     train(epoch)
# ---> 11     test()
#      12     if epoch_state['test_accuracy'] > best_accuracy:
#      13         best_accuracy = epoch_state['test_accuracy']
#
# <ipython-input-7-1de7f46dd3bb> in test()
#      36         # forward
#      37         output = resnext_model(data)
# ---> 38         loss = F.cross_entropy(output, target)
#      39
#      40         # accuracy
#
# /opt/conda/lib/python2.7/site-packages/torch/nn/functional.pyc in cross_entropy(input, target, weight, size_average, ignore_index, reduce)
#    1159         >>> loss.backward()
#    1160     """
# -> 1161     return nll_loss(log_softmax(input, 1), target, weight, size_average, ignore_index, reduce)
#    1162
#    1163
#
# /opt/conda/lib/python2.7/site-packages/torch/nn/functional.pyc in nll_loss(input, target, weight, size_average, ignore_index, reduce)
#    1050         weight = Variable(weight)
#    1051     if dim == 2:
# -> 1052         return torch._C._nn.nll_loss(input, target, weight, size_average, ignore_index, reduce)
#    1053     elif dim == 4:
#    1054         return torch._C._nn.nll_loss2d(input, target, weight, size_average, ignore_index, reduce)
#
# RuntimeError: invalid argument 2: mismatch between the batch size of input (800) and that of target (32) at /opt/conda/conda-bld/pytorch_1523240155148/work/torch/lib/THCUNN/generic/ClassNLLCriterion.cu:39
