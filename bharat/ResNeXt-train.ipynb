# %% [markdown]
# # Training ResNeXt

# %% [markdown]
# This Notebook will go through the process of training the ResNeXt model with an architecture that is optimized for the Cifar Dataset (as specified in [1] https://arxiv.org/pdf/1611.05431.pdf).

# %%
import os
import sys
import json
import shutil
import torch
import torch.nn.functional as F
import torchvision.datasets as dset
import torchvision.transforms as transforms
import time

# %%
sys.path.append("..") # Note, this line is needed only since this notebook is being run from inside 'bharat' directory
                      # If you run this notebook in the same folder as the the 'models-py-code' directory, remove this line
from pymodels.resnext import CifarResNeXt # This is where we actually refer to the model we wish to train

# %% [markdown]
# ## Set all required parameters
# Remember to change the `session_id` for each new model you wish to train or if you change of the other parameters

# %%
args={}

# Input Data Parameters
args['data_path'] = '/datasets/ee285s-public/'
args['dataset'] = 'cifar100' # The other option is 'cifar10'

# Optimization options
args['epochs'] = 300
args['start_epoch'] = 0 # Change only if necessary. Used for resuming sessions
args['batch_size'] = 96
args['learning_rate'] = 0.1
args['momentum'] = 0.9 # Momentum
args['decay'] = 0.0005 # Weight decay (L2 penalty)
args['test_bs'] = 64 # Test Batch Size
args['schedule'] = [75, 150] # Decrease learning rate at these epochs
args['gamma'] = 0.1 # LR is multiplied by gamma on schedule.

# Checkpoints and Session Parameters
args['save_dir'] = './' # Folder to save checkpoint file and best model file
args['load'] = 'resnext-0-checkpoint.pth' # Path to load Checkpoint file 
args['session_id'] = '0' # Remember to change the session id for each new model you train

# Architecture
args['depth'] = 29 # Model depth
args['cardinality'] = 8 # Model cardinality (group)
args['base_width'] = 64 # Number of channels in each group
args['widen_factor'] = 4 # Widen factor. 4 -> 64, 8 -> 128, ...

# Acceleration
args['ngpu'] = 1 # 0 = CPU
args['prefetch'] = 2 # Pre-fetching threads

# i/o
args['log_dir'] = './log/' # Log folder

# %% [markdown]
# ### Initialize Logging

# %%
if not os.path.isdir(args['log_dir']):
        os.makedirs(args['log_dir'])
if args['load'] == '':
    log = open(os.path.join(args['log_dir'], 'resnext-{}-log.txt'.format(args['session_id'])), 'w')
else:
    log = open(os.path.join(args['log_dir'], 'resnext-{}-log.txt'.format(args['session_id'])), 'a')

# %% [markdown]
# ### Setup the Input Data

# %%
mean = [x / 255 for x in [125.3, 123.0, 113.9]]
std = [x / 255 for x in [63.0, 62.1, 66.7]]

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomCrop(32, padding=4),
     transforms.ToTensor(),
     transforms.Normalize(mean, std)])

test_transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean, std)])

if args['dataset'] == 'cifar10':
    train_data = dset.CIFAR10(args['data_path'], train=True, transform=train_transform, download=False)
    test_data = dset.CIFAR10(args['data_path'], train=False, transform=test_transform, download=False)
    nlabels = 10
else:
    train_data = dset.CIFAR100(args['data_path'], train=True, transform=train_transform, download=False)
    test_data = dset.CIFAR100(args['data_path'], train=False, transform=test_transform, download=False)
    nlabels = 100

train_loader = torch.utils.data.DataLoader(train_data, batch_size=args['batch_size'], shuffle=True,
                                                                       num_workers=args['prefetch'], pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=args['test_bs'], shuffle=False,
                                                                     num_workers=args['prefetch'], pin_memory=True)

# %% [markdown]
# ### Setup the Model, Criterion, and Optimizer

# %%
resnext_model = CifarResNeXt(args['cardinality'], args['depth'], nlabels, args['base_width'], args['widen_factor'])
print(resnext_model)
if args['ngpu'] > 1:
    resnext_model = torch.nn.DataParallel(resnext_model, device_ids=list(range(args['ngpu'])))

if args['ngpu'] > 0:
    resnext_model.cuda()

optimizer = torch.optim.SGD(resnext_model.parameters(), args['learning_rate'], momentum=args['momentum'],
                            weight_decay=args['decay'], nesterov=True)
# Out:
# CifarResNeXt(
#   (conv_1_3x3): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (stage_1): Sequential(
#     (stage_1_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (shortcut_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_1_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_1_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (stage_2): Sequential(
#     (stage_2_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (shortcut_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_2_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_2_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (stage_3): Sequential(
#     (stage_3_bottleneck_0): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#         (shortcut_conv): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (shortcut_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       )
#     )
#     (stage_3_bottleneck_1): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#     (stage_3_bottleneck_2): ResNeXtBottleneck(
#       (conv_reduce): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_reduce): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_conv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (bn): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#       (conv_expand): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn_expand): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True)
#       (shortcut): Sequential(
#       )
#     )
#   )
#   (classifier): Linear(in_features=1024, out_features=100, bias=True)
# )

# %% [markdown]
# ### Setup the Train and Test Functions

# %%
def train(epoch):
    resnext_model.train()
    loss_avg = 0.0
    t0 = time.time()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = torch.autograd.Variable(data.cuda()), torch.autograd.Variable(target.cuda())

        # forward
        output = resnext_model(data)

        # backward
        optimizer.zero_grad()
        t0 = time.time()
        loss = F.cross_entropy(output, target)
        t1 = time.time()
        loss.backward()
        optimizer.step()

        # exponential moving average
        loss_avg = loss_avg * 0.2 + float(loss) * 0.8

        print("===> Epoch[{}]({}/{}): Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, batch_idx, len(train_loader), loss.data[0], (t1 - t0)))

    epoch_state['train_loss'] = loss_avg
    t1 = time.time()
    print("===> Epoch {} Complete: Avg. Loss: {:.4f} | Time: {:.4f}".format(epoch, loss_avg, (t1-t0)))

# test function (forward only)
def test():
    resnext_model.eval()
    loss_avg = 0.0
    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        data, target = torch.autograd.Variable(data.cuda()), torch.autograd.Variable(target.cuda())

        # forward
        output = resnext_model(data)
        loss = F.cross_entropy(output, target)

        # accuracy
        pred = output.data.max(1)[1]
        correct += float(pred.eq(target.data).sum())

        # test loss average
        loss_avg += float(loss)

    epoch_state['test_loss'] = loss_avg / len(test_loader)
    epoch_state['test_accuracy'] = correct / len(test_loader.dataset)

# %% [markdown]
# ### Define a function to save a checkpoint

# %%
def save_checkpoint(state, is_best, filename='resnext-{}-checkpoint.pth'.format(args['session_id'])):
    filepath = os.path.join(args['save_dir'], filename)
    torch.save(state, filepath)
    if is_best:
        bestfilepath = os.path.join(args['save_dir'], 'model-best-resnext-{}.pth'.format(args['session_id']))
        shutil.copyfile(filepath, bestfilepath)

# %% [markdown]
# ### Load and Resume from checkpoint (if set)

# %%
if not args['load'] == '':
    if os.path.isfile(args['load']):
        print("=> Loading Checkpoint '{}'".format(args['load']))
        checkpoint = torch.load(args['load'])
        args['start_epoch'] = checkpoint['epoch'] + 1
        resnext_model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("=> Loaded checkpoint '{}' (epoch {})"
              .format(args['load'], checkpoint['epoch']))
    else:
        print("=> No checkpoint found at '{}'".format(args['load']))
# Out:
# => Loading Checkpoint 'resnext-0-checkpoint.pth'
# => Loaded checkpoint 'resnext-0-checkpoint.pth' (epoch 38)

# %% [markdown]
# ### Main Loop

# %%
best_accuracy = 0.0
epoch_state = {'args' : args}
for epoch in range(args['start_epoch'], args['epochs']):
    if epoch in args['schedule']:
        epoch_state['learning_rate'] *= args['gamma']
        for param_group in optimizer.param_groups:
            param_group['lr'] = epoch_state['learning_rate']

    epoch_state['epoch'] = epoch
    train(epoch)
    test()
    if epoch_state['test_accuracy'] > best_accuracy:
        best_accuracy = epoch_state['test_accuracy']
        isbest = True
    
    save_checkpoint({
        'epoch' : epoch,
        'state_dict' : resnext_model.state_dict(),
        'optimizer' : optimizer.state_dict()
    }, isbest)
    
    log.write('%s\n' % json.dumps(epoch_state))
    log.flush()
    #print(epoch_state)
    print("[Epoch {}] Best accuracy: {:.4f}".format(epoch, best_accuracy))

log.close()
# Out:
# ===> Epoch[39](0/521): Loss: 0.9516 || Timer: 0.0015 sec.
# ===> Epoch[39](1/521): Loss: 1.2045 || Timer: 0.0004 sec.
# ===> Epoch[39](2/521): Loss: 0.7910 || Timer: 0.0002 sec.
# ===> Epoch[39](3/521): Loss: 1.0417 || Timer: 0.0003 sec.
# ===> Epoch[39](4/521): Loss: 1.0221 || Timer: 0.0005 sec.
# ===> Epoch[39](5/521): Loss: 0.9995 || Timer: 0.0003 sec.
# ===> Epoch[39](6/521): Loss: 0.9543 || Timer: 0.0002 sec.
# ===> Epoch[39](7/521): Loss: 1.0648 || Timer: 0.0005 sec.
# ===> Epoch[39](8/521): Loss: 1.1851 || Timer: 0.0003 sec.
# ===> Epoch[39](9/521): Loss: 0.9705 || Timer: 0.0002 sec.
# ===> Epoch[39](10/521): Loss: 1.2722 || Timer: 0.0003 sec.
# ===> Epoch[39](11/521): Loss: 0.8576 || Timer: 0.0004 sec.
# ===> Epoch[39](12/521): Loss: 0.8488 || Timer: 0.0002 sec.
# ===> Epoch[39](13/521): Loss: 0.8266 || Timer: 0.0002 sec.
# ===> Epoch[39](14/521): Loss: 1.1461 || Timer: 0.0002 sec.
# ===> Epoch[39](15/521): Loss: 0.8802 || Timer: 0.0003 sec.
# ===> Epoch[39](16/521): Loss: 0.8214 || Timer: 0.0003 sec.
# ===> Epoch[39](17/521): Loss: 0.9094 || Timer: 0.0003 sec.
# ===> Epoch[39](18/521): Loss: 0.9293 || Timer: 0.0002 sec.
# ===> Epoch[39](19/521): Loss: 0.9632 || Timer: 0.0003 sec.
# ===> Epoch[39](20/521): Loss: 1.2321 || Timer: 0.0003 sec.
# ===> Epoch[39](21/521): Loss: 0.7195 || Timer: 0.0003 sec.
# ===> Epoch[39](22/521): Loss: 1.0968 || Timer: 0.0002 sec.
# ===> Epoch[39](23/521): Loss: 0.9863 || Timer: 0.0002 sec.
# ===> Epoch[39](24/521): Loss: 0.9709 || Timer: 0.0002 sec.
# ===> Epoch[39](25/521): Loss: 0.8203 || Timer: 0.0003 sec.
# ===> Epoch[39](26/521): Loss: 1.1600 || Timer: 0.0002 sec.
# ===> Epoch[39](27/521): Loss: 1.0952 || Timer: 0.0002 sec.
# ===> Epoch[39](28/521): Loss: 1.1441 || Timer: 0.0003 sec.
# ===> Epoch[39](29/521): Loss: 0.8413 || Timer: 0.0002 sec.
# ===> Epoch[39](30/521): Loss: 0.7572 || Timer: 0.0002 sec.
# ===> Epoch[39](31/521): Loss: 1.1392 || Timer: 0.0002 sec.
# ===> Epoch[39](32/521): Loss: 0.9740 || Timer: 0.0003 sec.
# ===> Epoch[39](33/521): Loss: 0.6918 || Timer: 0.0002 sec.
# ===> Epoch[39](34/521): Loss: 1.1998 || Timer: 0.0002 sec.
# ===> Epoch[39](35/521): Loss: 0.8491 || Timer: 0.0002 sec.
# ===> Epoch[39](36/521): Loss: 0.9607 || Timer: 0.0002 sec.
# ===> Epoch[39](37/521): Loss: 0.8086 || Timer: 0.0002 sec.
# ===> Epoch[39](38/521): Loss: 0.9076 || Timer: 0.0002 sec.
# ===> Epoch[39](39/521): Loss: 1.0083 || Timer: 0.0002 sec.
# ===> Epoch[39](40/521): Loss: 1.0167 || Timer: 0.0002 sec.
# ===> Epoch[39](41/521): Loss: 0.9041 || Timer: 0.0002 sec.
# ===> Epoch[39](42/521): Loss: 0.9897 || Timer: 0.0002 sec.
# ===> Epoch[39](43/521): Loss: 1.0587 || Timer: 0.0002 sec.
# ===> Epoch[39](44/521): Loss: 0.7957 || Timer: 0.0002 sec.
# ===> Epoch[39](45/521): Loss: 0.8853 || Timer: 0.0003 sec.
# ===> Epoch[39](46/521): Loss: 0.9197 || Timer: 0.0002 sec.
# ===> Epoch[39](47/521): Loss: 0.8377 || Timer: 0.0002 sec.
# ===> Epoch[39](48/521): Loss: 0.8260 || Timer: 0.0002 sec.
# ===> Epoch[39](49/521): Loss: 0.9326 || Timer: 0.0002 sec.
# ===> Epoch[39](50/521): Loss: 0.9268 || Timer: 0.0002 sec.
# ===> Epoch[39](51/521): Loss: 0.9459 || Timer: 0.0002 sec.
# ===> Epoch[39](52/521): Loss: 1.1244 || Timer: 0.0002 sec.
# ===> Epoch[39](53/521): Loss: 1.0482 || Timer: 0.0002 sec.
# ===> Epoch[39](54/521): Loss: 1.0569 || Timer: 0.0002 sec.
# ===> Epoch[39](55/521): Loss: 0.9759 || Timer: 0.0003 sec.
# ===> Epoch[39](56/521): Loss: 0.7512 || Timer: 0.0003 sec.
# ===> Epoch[39](57/521): Loss: 1.0160 || Timer: 0.0002 sec.
# ===> Epoch[39](58/521): Loss: 1.0229 || Timer: 0.0003 sec.
# ===> Epoch[39](59/521): Loss: 0.9215 || Timer: 0.0002 sec.
# ===> Epoch[39](60/521): Loss: 1.0973 || Timer: 0.0002 sec.
# ===> Epoch[39](61/521): Loss: 1.0540 || Timer: 0.0002 sec.
# ===> Epoch[39](62/521): Loss: 0.9135 || Timer: 0.0003 sec.
# ===> Epoch[39](63/521): Loss: 0.8961 || Timer: 0.0002 sec.
# ===> Epoch[39](64/521): Loss: 1.2296 || Timer: 0.0002 sec.
# ===> Epoch[39](65/521): Loss: 1.1960 || Timer: 0.0002 sec.
# ===> Epoch[39](66/521): Loss: 1.0625 || Timer: 0.0002 sec.
# ===> Epoch[39](67/521): Loss: 0.7907 || Timer: 0.0002 sec.
# ===> Epoch[39](68/521): Loss: 1.0208 || Timer: 0.0003 sec.
# ===> Epoch[39](69/521): Loss: 0.8924 || Timer: 0.0002 sec.
# ===> Epoch[39](70/521): Loss: 1.0518 || Timer: 0.0003 sec.
# ===> Epoch[39](71/521): Loss: 1.2405 || Timer: 0.0002 sec.
# ===> Epoch[39](72/521): Loss: 1.0222 || Timer: 0.0002 sec.
# ===> Epoch[39](73/521): Loss: 0.7927 || Timer: 0.0002 sec.
# ===> Epoch[39](74/521): Loss: 0.9656 || Timer: 0.0003 sec.
# ===> Epoch[39](75/521): Loss: 0.9110 || Timer: 0.0002 sec.
# ===> Epoch[39](76/521): Loss: 0.8201 || Timer: 0.0002 sec.
# ===> Epoch[39](77/521): Loss: 0.9443 || Timer: 0.0002 sec.
# ===> Epoch[39](78/521): Loss: 1.1056 || Timer: 0.0002 sec.
# ===> Epoch[39](79/521): Loss: 1.1636 || Timer: 0.0002 sec.
# ===> Epoch[39](80/521): Loss: 1.1087 || Timer: 0.0002 sec.
# ===> Epoch[39](81/521): Loss: 0.9291 || Timer: 0.0002 sec.
# ===> Epoch[39](82/521): Loss: 0.8066 || Timer: 0.0002 sec.
# ===> Epoch[39](83/521): Loss: 1.0705 || Timer: 0.0002 sec.
# ===> Epoch[39](84/521): Loss: 0.9494 || Timer: 0.0002 sec.
# ===> Epoch[39](85/521): Loss: 0.8992 || Timer: 0.0002 sec.
# ===> Epoch[39](86/521): Loss: 1.0201 || Timer: 0.0002 sec.
# ===> Epoch[39](87/521): Loss: 0.9645 || Timer: 0.0002 sec.
# ===> Epoch[39](88/521): Loss: 1.1577 || Timer: 0.0002 sec.
# ===> Epoch[39](89/521): Loss: 0.8458 || Timer: 0.0002 sec.
# ===> Epoch[39](90/521): Loss: 0.9273 || Timer: 0.0002 sec.
# ===> Epoch[39](91/521): Loss: 1.0767 || Timer: 0.0002 sec.
# ===> Epoch[39](92/521): Loss: 0.8816 || Timer: 0.0002 sec.
# ===> Epoch[39](93/521): Loss: 0.7625 || Timer: 0.0002 sec.
# ===> Epoch[39](94/521): Loss: 0.8296 || Timer: 0.0002 sec.
# ===> Epoch[39](95/521): Loss: 0.8138 || Timer: 0.0002 sec.
# ===> Epoch[39](96/521): Loss: 0.9731 || Timer: 0.0002 sec.
# ===> Epoch[39](97/521): Loss: 1.4164 || Timer: 0.0002 sec.
# ===> Epoch[39](98/521): Loss: 1.0402 || Timer: 0.0003 sec.
# ===> Epoch[39](99/521): Loss: 1.1301 || Timer: 0.0002 sec.
# ===> Epoch[39](100/521): Loss: 0.7665 || Timer: 0.0002 sec.
# ===> Epoch[39](101/521): Loss: 1.1658 || Timer: 0.0002 sec.
# ===> Epoch[39](102/521): Loss: 0.9521 || Timer: 0.0002 sec.
# ===> Epoch[39](103/521): Loss: 1.1068 || Timer: 0.0002 sec.
# ===> Epoch[39](104/521): Loss: 0.9520 || Timer: 0.0004 sec.
# ===> Epoch[39](105/521): Loss: 0.9128 || Timer: 0.0003 sec.
# ===> Epoch[39](106/521): Loss: 0.8715 || Timer: 0.0003 sec.
# ===> Epoch[39](107/521): Loss: 1.0104 || Timer: 0.0002 sec.
# ===> Epoch[39](108/521): Loss: 0.7351 || Timer: 0.0003 sec.
# ===> Epoch[39](109/521): Loss: 0.9506 || Timer: 0.0003 sec.
# ===> Epoch[39](110/521): Loss: 0.9242 || Timer: 0.0002 sec.
# ===> Epoch[39](111/521): Loss: 1.0089 || Timer: 0.0002 sec.
# ===> Epoch[39](112/521): Loss: 0.8223 || Timer: 0.0002 sec.
# ===> Epoch[39](113/521): Loss: 0.8412 || Timer: 0.0002 sec.
# ===> Epoch[39](114/521): Loss: 0.8437 || Timer: 0.0002 sec.
# ===> Epoch[39](115/521): Loss: 1.0023 || Timer: 0.0002 sec.
# ===> Epoch[39](116/521): Loss: 0.9909 || Timer: 0.0002 sec.
# ===> Epoch[39](117/521): Loss: 1.0718 || Timer: 0.0002 sec.
# ===> Epoch[39](118/521): Loss: 0.9760 || Timer: 0.0002 sec.
# ===> Epoch[39](119/521): Loss: 0.9997 || Timer: 0.0002 sec.
# ===> Epoch[39](120/521): Loss: 1.0912 || Timer: 0.0002 sec.
# ===> Epoch[39](121/521): Loss: 0.9786 || Timer: 0.0002 sec.
# ===> Epoch[39](122/521): Loss: 0.9214 || Timer: 0.0002 sec.
# ===> Epoch[39](123/521): Loss: 1.1332 || Timer: 0.0002 sec.
# ===> Epoch[39](124/521): Loss: 0.9767 || Timer: 0.0002 sec.
# ===> Epoch[39](125/521): Loss: 1.1250 || Timer: 0.0002 sec.
# ===> Epoch[39](126/521): Loss: 0.8539 || Timer: 0.0002 sec.
# ===> Epoch[39](127/521): Loss: 1.1020 || Timer: 0.0002 sec.
# ===> Epoch[39](128/521): Loss: 1.1925 || Timer: 0.0002 sec.
# ===> Epoch[39](129/521): Loss: 0.9233 || Timer: 0.0002 sec.
# ===> Epoch[39](130/521): Loss: 0.9819 || Timer: 0.0002 sec.
# ===> Epoch[39](131/521): Loss: 0.8011 || Timer: 0.0002 sec.
# ===> Epoch[39](132/521): Loss: 1.0193 || Timer: 0.0002 sec.
# ===> Epoch[39](133/521): Loss: 1.0151 || Timer: 0.0002 sec.
# ===> Epoch[39](134/521): Loss: 0.8582 || Timer: 0.0002 sec.
# ===> Epoch[39](135/521): Loss: 1.3502 || Timer: 0.0002 sec.
# ===> Epoch[39](136/521): Loss: 1.1227 || Timer: 0.0002 sec.
# ===> Epoch[39](137/521): Loss: 0.9714 || Timer: 0.0002 sec.
# ===> Epoch[39](138/521): Loss: 1.1158 || Timer: 0.0002 sec.
# ===> Epoch[39](139/521): Loss: 0.9178 || Timer: 0.0002 sec.
# ===> Epoch[39](140/521): Loss: 0.9447 || Timer: 0.0002 sec.
# ===> Epoch[39](141/521): Loss: 0.8855 || Timer: 0.0002 sec.
# ===> Epoch[39](142/521): Loss: 0.9994 || Timer: 0.0002 sec.
# ===> Epoch[39](143/521): Loss: 1.3385 || Timer: 0.0002 sec.
# ===> Epoch[39](144/521): Loss: 1.1263 || Timer: 0.0002 sec.
# ===> Epoch[39](145/521): Loss: 1.0224 || Timer: 0.0002 sec.
# ===> Epoch[39](146/521): Loss: 0.8236 || Timer: 0.0002 sec.
# ===> Epoch[39](147/521): Loss: 1.1117 || Timer: 0.0002 sec.
# ===> Epoch[39](148/521): Loss: 1.0006 || Timer: 0.0002 sec.
# ===> Epoch[39](149/521): Loss: 1.0253 || Timer: 0.0002 sec.
# ===> Epoch[39](150/521): Loss: 0.8203 || Timer: 0.0002 sec.
# ===> Epoch[39](151/521): Loss: 0.9378 || Timer: 0.0001 sec.
# ===> Epoch[39](152/521): Loss: 1.3077 || Timer: 0.0002 sec.
# ===> Epoch[39](153/521): Loss: 1.2198 || Timer: 0.0002 sec.
# ===> Epoch[39](154/521): Loss: 0.9018 || Timer: 0.0002 sec.
# ===> Epoch[39](155/521): Loss: 1.1103 || Timer: 0.0002 sec.
# ===> Epoch[39](156/521): Loss: 1.0201 || Timer: 0.0002 sec.
# ===> Epoch[39](157/521): Loss: 1.2506 || Timer: 0.0002 sec.
# ===> Epoch[39](158/521): Loss: 0.8113 || Timer: 0.0002 sec.
# ===> Epoch[39](159/521): Loss: 0.9951 || Timer: 0.0002 sec.
# ===> Epoch[39](160/521): Loss: 0.8565 || Timer: 0.0002 sec.
# ===> Epoch[39](161/521): Loss: 1.2270 || Timer: 0.0002 sec.
# ===> Epoch[39](162/521): Loss: 0.9154 || Timer: 0.0002 sec.
# ===> Epoch[39](163/521): Loss: 0.9240 || Timer: 0.0002 sec.
# ===> Epoch[39](164/521): Loss: 1.1339 || Timer: 0.0002 sec.
# ===> Epoch[39](165/521): Loss: 1.1159 || Timer: 0.0002 sec.
# ===> Epoch[39](166/521): Loss: 1.0204 || Timer: 0.0002 sec.
# ===> Epoch[39](167/521): Loss: 1.3228 || Timer: 0.0002 sec.
# ===> Epoch[39](168/521): Loss: 0.8887 || Timer: 0.0002 sec.
# ===> Epoch[39](169/521): Loss: 0.8580 || Timer: 0.0002 sec.
# ===> Epoch[39](170/521): Loss: 1.2560 || Timer: 0.0002 sec.
# ===> Epoch[39](171/521): Loss: 0.8035 || Timer: 0.0003 sec.
# ===> Epoch[39](172/521): Loss: 0.9101 || Timer: 0.0002 sec.
# ===> Epoch[39](173/521): Loss: 1.0770 || Timer: 0.0002 sec.
# ===> Epoch[39](174/521): Loss: 1.1135 || Timer: 0.0002 sec.
# ===> Epoch[39](175/521): Loss: 0.7940 || Timer: 0.0002 sec.
# ===> Epoch[39](176/521): Loss: 0.9615 || Timer: 0.0002 sec.
# ===> Epoch[39](177/521): Loss: 0.9011 || Timer: 0.0002 sec.
# ===> Epoch[39](178/521): Loss: 0.9898 || Timer: 0.0002 sec.
# ===> Epoch[39](179/521): Loss: 0.7246 || Timer: 0.0002 sec.
# ===> Epoch[39](180/521): Loss: 0.9546 || Timer: 0.0002 sec.
# ===> Epoch[39](181/521): Loss: 0.7869 || Timer: 0.0002 sec.
# ===> Epoch[39](182/521): Loss: 1.0557 || Timer: 0.0002 sec.
# ===> Epoch[39](183/521): Loss: 0.9323 || Timer: 0.0002 sec.
# ===> Epoch[39](184/521): Loss: 0.8120 || Timer: 0.0002 sec.
# ===> Epoch[39](185/521): Loss: 1.1658 || Timer: 0.0008 sec.
# ===> Epoch[39](186/521): Loss: 0.9985 || Timer: 0.0002 sec.
# ===> Epoch[39](187/521): Loss: 0.9164 || Timer: 0.0002 sec.
# ===> Epoch[39](188/521): Loss: 1.1366 || Timer: 0.0002 sec.
# ===> Epoch[39](189/521): Loss: 0.8598 || Timer: 0.0002 sec.
# ===> Epoch[39](190/521): Loss: 0.7161 || Timer: 0.0002 sec.
# ===> Epoch[39](191/521): Loss: 1.0832 || Timer: 0.0002 sec.
# ===> Epoch[39](192/521): Loss: 1.2308 || Timer: 0.0002 sec.
# ===> Epoch[39](193/521): Loss: 0.9766 || Timer: 0.0002 sec.
# ===> Epoch[39](410/521): Loss: 0.9505 || Timer: 0.0002 sec.
# ===> Epoch[39](411/521): Loss: 1.3106 || Timer: 0.0002 sec.
# ===> Epoch[39](412/521): Loss: 1.0205 || Timer: 0.0002 sec.
# ===> Epoch[39](413/521): Loss: 0.8738 || Timer: 0.0002 sec.
# ===> Epoch[39](414/521): Loss: 1.2314 || Timer: 0.0002 sec.
# ===> Epoch[39](415/521): Loss: 1.1988 || Timer: 0.0002 sec.
# ===> Epoch[39](416/521): Loss: 0.9242 || Timer: 0.0002 sec.
# ===> Epoch[39](417/521): Loss: 1.0489 || Timer: 0.0002 sec.
# ===> Epoch[39](418/521): Loss: 1.1335 || Timer: 0.0002 sec.
# ===> Epoch[39](419/521): Loss: 1.2239 || Timer: 0.0002 sec.
# ===> Epoch[39](420/521): Loss: 1.1281 || Timer: 0.0002 sec.
# ===> Epoch[39](421/521): Loss: 1.0592 || Timer: 0.0002 sec.
# ===> Epoch[39](422/521): Loss: 1.0929 || Timer: 0.0002 sec.
# ===> Epoch[39](423/521): Loss: 1.3301 || Timer: 0.0002 sec.
# ===> Epoch[39](424/521): Loss: 1.0816 || Timer: 0.0002 sec.
# ===> Epoch[39](425/521): Loss: 0.7757 || Timer: 0.0002 sec.
# ===> Epoch[39](426/521): Loss: 1.2363 || Timer: 0.0002 sec.
# ===> Epoch[39](427/521): Loss: 0.9464 || Timer: 0.0002 sec.
# ===> Epoch[39](428/521): Loss: 0.9679 || Timer: 0.0002 sec.
# ===> Epoch[39](429/521): Loss: 1.0757 || Timer: 0.0002 sec.
# ===> Epoch[39](430/521): Loss: 1.2449 || Timer: 0.0002 sec.
# ===> Epoch[39](431/521): Loss: 1.0008 || Timer: 0.0002 sec.
# ===> Epoch[39](432/521): Loss: 1.1425 || Timer: 0.0002 sec.
# ===> Epoch[39](433/521): Loss: 0.9199 || Timer: 0.0002 sec.
# ===> Epoch[39](434/521): Loss: 1.0716 || Timer: 0.0002 sec.
# ===> Epoch[39](435/521): Loss: 1.0902 || Timer: 0.0002 sec.
# ===> Epoch[39](436/521): Loss: 1.1108 || Timer: 0.0002 sec.
# ===> Epoch[39](437/521): Loss: 0.9151 || Timer: 0.0002 sec.
# ===> Epoch[39](438/521): Loss: 1.0370 || Timer: 0.0002 sec.
# ===> Epoch[39](439/521): Loss: 1.3277 || Timer: 0.0002 sec.
# ===> Epoch[39](440/521): Loss: 1.0370 || Timer: 0.0002 sec.
# ===> Epoch[39](441/521): Loss: 1.0405 || Timer: 0.0002 sec.
# ===> Epoch[39](442/521): Loss: 1.1045 || Timer: 0.0002 sec.
# ===> Epoch[39](443/521): Loss: 0.9633 || Timer: 0.0002 sec.
# ===> Epoch[39](444/521): Loss: 1.3074 || Timer: 0.0002 sec.
# ===> Epoch[39](445/521): Loss: 0.8943 || Timer: 0.0002 sec.
# ===> Epoch[39](446/521): Loss: 1.1562 || Timer: 0.0003 sec.
# ===> Epoch[39](447/521): Loss: 0.9908 || Timer: 0.0002 sec.
# ===> Epoch[39](448/521): Loss: 0.9637 || Timer: 0.0002 sec.
# ===> Epoch[39](449/521): Loss: 1.2670 || Timer: 0.0002 sec.
# ===> Epoch[39](450/521): Loss: 1.0821 || Timer: 0.0001 sec.
# ===> Epoch[39](451/521): Loss: 0.9616 || Timer: 0.0002 sec.
# ===> Epoch[39](452/521): Loss: 1.0649 || Timer: 0.0002 sec.
# ===> Epoch[39](453/521): Loss: 1.0897 || Timer: 0.0002 sec.
# ===> Epoch[39](454/521): Loss: 1.3267 || Timer: 0.0002 sec.
# ===> Epoch[39](455/521): Loss: 1.0657 || Timer: 0.0002 sec.
# ===> Epoch[39](456/521): Loss: 1.1201 || Timer: 0.0002 sec.
# ===> Epoch[39](457/521): Loss: 0.8769 || Timer: 0.0002 sec.
# ===> Epoch[39](458/521): Loss: 0.9388 || Timer: 0.0002 sec.
# ===> Epoch[39](459/521): Loss: 1.0516 || Timer: 0.0002 sec.
# ===> Epoch[39](460/521): Loss: 1.0366 || Timer: 0.0002 sec.
# ===> Epoch[39](461/521): Loss: 0.8351 || Timer: 0.0002 sec.
# ===> Epoch[39](462/521): Loss: 1.1677 || Timer: 0.0002 sec.
# ===> Epoch[39](463/521): Loss: 1.1270 || Timer: 0.0002 sec.
# ===> Epoch[39](464/521): Loss: 1.2545 || Timer: 0.0002 sec.
# ===> Epoch[39](465/521): Loss: 1.0924 || Timer: 0.0002 sec.
# ===> Epoch[39](466/521): Loss: 1.2944 || Timer: 0.0002 sec.
# ===> Epoch[39](467/521): Loss: 1.1633 || Timer: 0.0002 sec.
# ===> Epoch[39](468/521): Loss: 1.0653 || Timer: 0.0002 sec.
# ===> Epoch[39](469/521): Loss: 1.2019 || Timer: 0.0002 sec.
# ===> Epoch[39](470/521): Loss: 1.0525 || Timer: 0.0002 sec.
# ===> Epoch[39](471/521): Loss: 1.2464 || Timer: 0.0002 sec.
# ===> Epoch[39](472/521): Loss: 0.9512 || Timer: 0.0002 sec.
# ===> Epoch[39](473/521): Loss: 1.0913 || Timer: 0.0002 sec.
# ===> Epoch[39](474/521): Loss: 1.1319 || Timer: 0.0002 sec.
# ===> Epoch[39](475/521): Loss: 1.0716 || Timer: 0.0002 sec.
# ===> Epoch[39](476/521): Loss: 1.0908 || Timer: 0.0002 sec.
# ===> Epoch[39](477/521): Loss: 0.7834 || Timer: 0.0002 sec.
# ===> Epoch[39](478/521): Loss: 1.1149 || Timer: 0.0002 sec.
# ===> Epoch[39](479/521): Loss: 0.8971 || Timer: 0.0002 sec.
# ===> Epoch[39](480/521): Loss: 1.1723 || Timer: 0.0002 sec.
# ===> Epoch[39](481/521): Loss: 1.0197 || Timer: 0.0002 sec.
# ===> Epoch[39](482/521): Loss: 1.3791 || Timer: 0.0002 sec.
# ===> Epoch[39](483/521): Loss: 1.0209 || Timer: 0.0002 sec.
# ===> Epoch[39](484/521): Loss: 0.9440 || Timer: 0.0002 sec.
# ===> Epoch[39](485/521): Loss: 0.9332 || Timer: 0.0002 sec.
# ===> Epoch[39](486/521): Loss: 0.9957 || Timer: 0.0002 sec.
# ===> Epoch[39](487/521): Loss: 1.1893 || Timer: 0.0002 sec.
# ===> Epoch[39](488/521): Loss: 0.9319 || Timer: 0.0002 sec.
# ===> Epoch[39](489/521): Loss: 1.0784 || Timer: 0.0002 sec.
# ===> Epoch[39](490/521): Loss: 1.2025 || Timer: 0.0002 sec.
# ===> Epoch[39](491/521): Loss: 1.3002 || Timer: 0.0002 sec.
# ===> Epoch[39](492/521): Loss: 1.3189 || Timer: 0.0002 sec.
# ===> Epoch[39](493/521): Loss: 1.2800 || Timer: 0.0002 sec.
# ===> Epoch[39](494/521): Loss: 1.3123 || Timer: 0.0002 sec.
# ===> Epoch[39](495/521): Loss: 0.9740 || Timer: 0.0002 sec.
# ===> Epoch[39](496/521): Loss: 0.9982 || Timer: 0.0002 sec.
# ===> Epoch[39](497/521): Loss: 1.1815 || Timer: 0.0002 sec.
# ===> Epoch[39](498/521): Loss: 0.7197 || Timer: 0.0002 sec.
# ===> Epoch[39](499/521): Loss: 1.1837 || Timer: 0.0002 sec.
# ===> Epoch[39](500/521): Loss: 1.1266 || Timer: 0.0002 sec.
# ===> Epoch[39](501/521): Loss: 1.0225 || Timer: 0.0001 sec.
# ===> Epoch[39](502/521): Loss: 1.2788 || Timer: 0.0001 sec.
# ===> Epoch[39](503/521): Loss: 1.0202 || Timer: 0.0001 sec.
# ===> Epoch[39](504/521): Loss: 1.2430 || Timer: 0.0001 sec.
# ===> Epoch[39](505/521): Loss: 0.9925 || Timer: 0.0003 sec.
# ===> Epoch[39](506/521): Loss: 1.1391 || Timer: 0.0002 sec.
# ===> Epoch[39](507/521): Loss: 0.8131 || Timer: 0.0002 sec.
# ===> Epoch[39](508/521): Loss: 1.2451 || Timer: 0.0002 sec.
# ===> Epoch[39](509/521): Loss: 0.9500 || Timer: 0.0002 sec.
# ===> Epoch[39](510/521): Loss: 1.0923 || Timer: 0.0002 sec.
# ===> Epoch[39](511/521): Loss: 1.3068 || Timer: 0.0002 sec.
# ===> Epoch[39](512/521): Loss: 1.0575 || Timer: 0.0002 sec.
# ===> Epoch[39](513/521): Loss: 0.8610 || Timer: 0.0002 sec.
# ===> Epoch[39](514/521): Loss: 0.9790 || Timer: 0.0002 sec.
# ===> Epoch[39](515/521): Loss: 1.1017 || Timer: 0.0002 sec.
# ===> Epoch[39](516/521): Loss: 1.0694 || Timer: 0.0002 sec.
# ===> Epoch[39](517/521): Loss: 1.1924 || Timer: 0.0002 sec.
# ===> Epoch[39](518/521): Loss: 1.2657 || Timer: 0.0002 sec.
# ===> Epoch[39](519/521): Loss: 1.0081 || Timer: 0.0002 sec.
# ===> Epoch[39](520/521): Loss: 1.1923 || Timer: 0.0002 sec.
# ===> Epoch 39 Complete: Avg. Loss: 1.1650 | Time: 0.3873
# [Epoch 39] Best accuracy: 0.5674
# ===> Epoch[40](0/521): Loss: 0.9231 || Timer: 0.0001 sec.
# ===> Epoch[40](1/521): Loss: 1.0398 || Timer: 0.0002 sec.
# ===> Epoch[40](2/521): Loss: 1.0975 || Timer: 0.0002 sec.
# ===> Epoch[40](3/521): Loss: 0.9072 || Timer: 0.0002 sec.
# ===> Epoch[40](4/521): Loss: 0.8784 || Timer: 0.0002 sec.
# ===> Epoch[40](5/521): Loss: 0.8479 || Timer: 0.0002 sec.
# ===> Epoch[40](6/521): Loss: 0.9679 || Timer: 0.0002 sec.
# ===> Epoch[40](7/521): Loss: 0.9758 || Timer: 0.0002 sec.
# ===> Epoch[40](8/521): Loss: 0.9503 || Timer: 0.0002 sec.
# ===> Epoch[40](9/521): Loss: 0.9199 || Timer: 0.0003 sec.
# ===> Epoch[40](10/521): Loss: 0.9049 || Timer: 0.0002 sec.
# ===> Epoch[40](11/521): Loss: 0.9059 || Timer: 0.0002 sec.
# ===> Epoch[40](12/521): Loss: 0.8388 || Timer: 0.0002 sec.
# ===> Epoch[40](13/521): Loss: 0.9685 || Timer: 0.0002 sec.
# ===> Epoch[40](14/521): Loss: 0.9544 || Timer: 0.0002 sec.
# ===> Epoch[40](15/521): Loss: 1.2127 || Timer: 0.0002 sec.
# ===> Epoch[40](16/521): Loss: 1.0216 || Timer: 0.0002 sec.
# ===> Epoch[40](17/521): Loss: 0.8526 || Timer: 0.0002 sec.
# ===> Epoch[40](18/521): Loss: 0.8839 || Timer: 0.0002 sec.
# ===> Epoch[40](19/521): Loss: 0.9807 || Timer: 0.0002 sec.
# ===> Epoch[40](20/521): Loss: 0.9711 || Timer: 0.0002 sec.
# ===> Epoch[40](21/521): Loss: 1.0428 || Timer: 0.0002 sec.
# ===> Epoch[40](22/521): Loss: 0.9141 || Timer: 0.0002 sec.
# ===> Epoch[40](23/521): Loss: 0.8731 || Timer: 0.0002 sec.
# ===> Epoch[40](24/521): Loss: 0.9785 || Timer: 0.0002 sec.
# ===> Epoch[40](25/521): Loss: 0.8491 || Timer: 0.0002 sec.
# ===> Epoch[40](26/521): Loss: 0.9088 || Timer: 0.0002 sec.
# ===> Epoch[40](27/521): Loss: 1.0197 || Timer: 0.0002 sec.
# ===> Epoch[40](28/521): Loss: 0.6771 || Timer: 0.0002 sec.
# ===> Epoch[40](29/521): Loss: 0.8293 || Timer: 0.0002 sec.
# ===> Epoch[40](30/521): Loss: 0.9105 || Timer: 0.0002 sec.
# ===> Epoch[40](31/521): Loss: 0.9766 || Timer: 0.0002 sec.
# ===> Epoch[40](32/521): Loss: 0.8989 || Timer: 0.0002 sec.
# ===> Epoch[40](33/521): Loss: 0.9600 || Timer: 0.0002 sec.
# ===> Epoch[40](34/521): Loss: 0.7803 || Timer: 0.0002 sec.
# ===> Epoch[40](35/521): Loss: 0.8560 || Timer: 0.0002 sec.
# ===> Epoch[40](36/521): Loss: 0.8614 || Timer: 0.0002 sec.
# ===> Epoch[40](37/521): Loss: 0.9400 || Timer: 0.0002 sec.
# ===> Epoch[40](38/521): Loss: 1.0146 || Timer: 0.0002 sec.
# ===> Epoch[40](39/521): Loss: 0.9150 || Timer: 0.0002 sec.
# ===> Epoch[40](40/521): Loss: 0.8946 || Timer: 0.0002 sec.
# ===> Epoch[40](41/521): Loss: 0.9313 || Timer: 0.0002 sec.
# ===> Epoch[40](42/521): Loss: 0.8865 || Timer: 0.0002 sec.
# ===> Epoch[40](43/521): Loss: 0.9158 || Timer: 0.0002 sec.
# ===> Epoch[40](44/521): Loss: 0.8490 || Timer: 0.0002 sec.
# ===> Epoch[40](45/521): Loss: 0.8849 || Timer: 0.0002 sec.
# ===> Epoch[40](46/521): Loss: 1.0646 || Timer: 0.0002 sec.
# ===> Epoch[40](47/521): Loss: 0.9522 || Timer: 0.0002 sec.
# ===> Epoch[40](48/521): Loss: 0.7089 || Timer: 0.0002 sec.
# ===> Epoch[40](49/521): Loss: 0.9165 || Timer: 0.0002 sec.
# ===> Epoch[40](50/521): Loss: 0.6518 || Timer: 0.0002 sec.
# ===> Epoch[40](51/521): Loss: 0.9510 || Timer: 0.0002 sec.
# ===> Epoch[40](52/521): Loss: 0.8182 || Timer: 0.0002 sec.
# ===> Epoch[40](53/521): Loss: 0.8691 || Timer: 0.0002 sec.
# ===> Epoch[40](54/521): Loss: 1.0096 || Timer: 0.0002 sec.
# ===> Epoch[40](55/521): Loss: 0.6702 || Timer: 0.0002 sec.
# ===> Epoch[40](56/521): Loss: 0.9463 || Timer: 0.0002 sec.
# ===> Epoch[40](57/521): Loss: 1.0208 || Timer: 0.0002 sec.
# ===> Epoch[40](58/521): Loss: 0.9548 || Timer: 0.0002 sec.
# ===> Epoch[40](59/521): Loss: 0.9241 || Timer: 0.0002 sec.
# ===> Epoch[40](60/521): Loss: 0.8812 || Timer: 0.0001 sec.
# ===> Epoch[40](61/521): Loss: 0.7914 || Timer: 0.0002 sec.
# ===> Epoch[40](62/521): Loss: 0.9487 || Timer: 0.0002 sec.
# ===> Epoch[40](63/521): Loss: 0.7118 || Timer: 0.0002 sec.
# ===> Epoch[40](64/521): Loss: 0.7806 || Timer: 0.0002 sec.
# ===> Epoch[40](65/521): Loss: 0.9051 || Timer: 0.0002 sec.
# ===> Epoch[40](66/521): Loss: 0.8729 || Timer: 0.0002 sec.
# ===> Epoch[40](67/521): Loss: 0.9189 || Timer: 0.0002 sec.
# ===> Epoch[40](68/521): Loss: 0.9063 || Timer: 0.0002 sec.
# ===> Epoch[40](69/521): Loss: 0.9849 || Timer: 0.0002 sec.
# ===> Epoch[40](70/521): Loss: 0.9541 || Timer: 0.0002 sec.
# ===> Epoch[40](71/521): Loss: 0.7739 || Timer: 0.0002 sec.
# ===> Epoch[40](72/521): Loss: 0.7128 || Timer: 0.0002 sec.
# ===> Epoch[40](73/521): Loss: 1.0912 || Timer: 0.0002 sec.
# ===> Epoch[40](74/521): Loss: 0.9275 || Timer: 0.0002 sec.
# ===> Epoch[40](75/521): Loss: 1.1710 || Timer: 0.0002 sec.
# ===> Epoch[40](76/521): Loss: 0.8042 || Timer: 0.0002 sec.
# ===> Epoch[40](77/521): Loss: 0.9036 || Timer: 0.0002 sec.
# ===> Epoch[40](78/521): Loss: 1.0981 || Timer: 0.0002 sec.
# ===> Epoch[40](79/521): Loss: 1.0597 || Timer: 0.0002 sec.
# ===> Epoch[40](80/521): Loss: 0.9207 || Timer: 0.0002 sec.
# ===> Epoch[40](81/521): Loss: 0.7647 || Timer: 0.0002 sec.
# ===> Epoch[40](82/521): Loss: 0.8680 || Timer: 0.0002 sec.
# ===> Epoch[40](83/521): Loss: 0.8229 || Timer: 0.0002 sec.
# ===> Epoch[40](84/521): Loss: 0.9734 || Timer: 0.0002 sec.
# ===> Epoch[40](85/521): Loss: 0.6883 || Timer: 0.0002 sec.
# ===> Epoch[40](86/521): Loss: 0.9098 || Timer: 0.0002 sec.
# ===> Epoch[40](87/521): Loss: 1.0639 || Timer: 0.0002 sec.
# ===> Epoch[40](88/521): Loss: 0.7409 || Timer: 0.0002 sec.
# ===> Epoch[40](89/521): Loss: 1.0303 || Timer: 0.0002 sec.
# ===> Epoch[40](90/521): Loss: 0.9328 || Timer: 0.0002 sec.
# ===> Epoch[40](91/521): Loss: 0.8282 || Timer: 0.0002 sec.
# ===> Epoch[40](92/521): Loss: 1.2051 || Timer: 0.0002 sec.
# ===> Epoch[40](93/521): Loss: 0.6601 || Timer: 0.0002 sec.
# ===> Epoch[40](94/521): Loss: 0.9661 || Timer: 0.0002 sec.
# ===> Epoch[40](95/521): Loss: 0.8209 || Timer: 0.0002 sec.
# ===> Epoch[40](96/521): Loss: 1.1305 || Timer: 0.0002 sec.
# ===> Epoch[40](97/521): Loss: 1.0125 || Timer: 0.0002 sec.
# ===> Epoch[40](98/521): Loss: 0.9674 || Timer: 0.0002 sec.
# ===> Epoch[40](99/521): Loss: 0.8999 || Timer: 0.0002 sec.
# ===> Epoch[40](100/521): Loss: 1.1573 || Timer: 0.0002 sec.
# ===> Epoch[40](101/521): Loss: 1.1094 || Timer: 0.0001 sec.
# ===> Epoch[40](102/521): Loss: 0.6462 || Timer: 0.0002 sec.
# ===> Epoch[40](103/521): Loss: 1.3401 || Timer: 0.0002 sec.
# ===> Epoch[40](104/521): Loss: 1.0898 || Timer: 0.0002 sec.
# ===> Epoch[40](105/521): Loss: 0.8790 || Timer: 0.0002 sec.
# ===> Epoch[40](106/521): Loss: 0.9813 || Timer: 0.0002 sec.
# ===> Epoch[40](107/521): Loss: 1.1820 || Timer: 0.0002 sec.
# ===> Epoch[40](108/521): Loss: 0.9781 || Timer: 0.0001 sec.
# ===> Epoch[40](109/521): Loss: 1.1028 || Timer: 0.0002 sec.
# ===> Epoch[40](110/521): Loss: 0.8473 || Timer: 0.0002 sec.
# ===> Epoch[40](111/521): Loss: 1.0487 || Timer: 0.0002 sec.
# ===> Epoch[40](112/521): Loss: 1.1214 || Timer: 0.0002 sec.
# ===> Epoch[40](113/521): Loss: 1.2631 || Timer: 0.0002 sec.
# ===> Epoch[40](114/521): Loss: 0.6777 || Timer: 0.0002 sec.
# ===> Epoch[40](115/521): Loss: 0.9806 || Timer: 0.0002 sec.
# ===> Epoch[40](116/521): Loss: 0.8694 || Timer: 0.0002 sec.
# ===> Epoch[40](117/521): Loss: 1.2120 || Timer: 0.0002 sec.
# ===> Epoch[40](118/521): Loss: 1.1012 || Timer: 0.0002 sec.
# ===> Epoch[40](119/521): Loss: 0.8917 || Timer: 0.0002 sec.
# ===> Epoch[40](120/521): Loss: 0.9228 || Timer: 0.0002 sec.
# ===> Epoch[40](121/521): Loss: 0.7710 || Timer: 0.0002 sec.
# ===> Epoch[40](122/521): Loss: 0.8642 || Timer: 0.0002 sec.
# ===> Epoch[40](123/521): Loss: 1.0127 || Timer: 0.0002 sec.
# ===> Epoch[40](124/521): Loss: 0.8187 || Timer: 0.0002 sec.
# ===> Epoch[40](125/521): Loss: 0.9527 || Timer: 0.0002 sec.
# ===> Epoch[40](126/521): Loss: 0.9745 || Timer: 0.0002 sec.
# ===> Epoch[40](127/521): Loss: 1.2339 || Timer: 0.0002 sec.
# ===> Epoch[40](128/521): Loss: 0.9358 || Timer: 0.0002 sec.
# ===> Epoch[40](129/521): Loss: 1.0612 || Timer: 0.0002 sec.
# ===> Epoch[40](130/521): Loss: 0.8986 || Timer: 0.0002 sec.
# ===> Epoch[40](131/521): Loss: 1.0462 || Timer: 0.0002 sec.
# ===> Epoch[40](132/521): Loss: 0.8478 || Timer: 0.0002 sec.
# ===> Epoch[40](133/521): Loss: 0.9361 || Timer: 0.0002 sec.
# ===> Epoch[40](134/521): Loss: 1.1942 || Timer: 0.0002 sec.
# ===> Epoch[40](135/521): Loss: 0.8490 || Timer: 0.0002 sec.
# ===> Epoch[40](136/521): Loss: 0.8658 || Timer: 0.0002 sec.
# ===> Epoch[40](137/521): Loss: 1.0684 || Timer: 0.0002 sec.
# ===> Epoch[40](138/521): Loss: 1.0214 || Timer: 0.0002 sec.
# ===> Epoch[40](139/521): Loss: 1.0164 || Timer: 0.0002 sec.
# ===> Epoch[40](140/521): Loss: 1.1165 || Timer: 0.0002 sec.
# ===> Epoch[40](141/521): Loss: 1.0481 || Timer: 0.0002 sec.
# ===> Epoch[40](142/521): Loss: 0.9701 || Timer: 0.0002 sec.
# ===> Epoch[40](143/521): Loss: 1.0135 || Timer: 0.0002 sec.
# ===> Epoch[40](144/521): Loss: 1.0270 || Timer: 0.0002 sec.
# ===> Epoch[40](145/521): Loss: 0.9649 || Timer: 0.0002 sec.
# ===> Epoch[40](146/521): Loss: 0.9828 || Timer: 0.0002 sec.
# ===> Epoch[40](147/521): Loss: 1.4126 || Timer: 0.0002 sec.
# ===> Epoch[40](148/521): Loss: 1.1441 || Timer: 0.0002 sec.
# ===> Epoch[40](149/521): Loss: 1.1385 || Timer: 0.0002 sec.
# ===> Epoch[40](150/521): Loss: 0.9926 || Timer: 0.0002 sec.
# ===> Epoch[40](151/521): Loss: 0.9084 || Timer: 0.0002 sec.
# ===> Epoch[40](152/521): Loss: 1.1582 || Timer: 0.0003 sec.
# ===> Epoch[40](153/521): Loss: 0.7453 || Timer: 0.0002 sec.
# ===> Epoch[40](154/521): Loss: 0.7072 || Timer: 0.0002 sec.
# ===> Epoch[40](155/521): Loss: 1.1953 || Timer: 0.0002 sec.
# ===> Epoch[40](156/521): Loss: 1.0399 || Timer: 0.0002 sec.
# ===> Epoch[40](157/521): Loss: 1.0842 || Timer: 0.0003 sec.
# ===> Epoch[40](158/521): Loss: 1.0060 || Timer: 0.0002 sec.
# ===> Epoch[40](159/521): Loss: 0.9412 || Timer: 0.0002 sec.
# ===> Epoch[40](160/521): Loss: 1.0444 || Timer: 0.0003 sec.
# ===> Epoch[40](161/521): Loss: 0.9131 || Timer: 0.0002 sec.
# ===> Epoch[40](162/521): Loss: 0.8236 || Timer: 0.0002 sec.
# ===> Epoch[40](163/521): Loss: 1.0573 || Timer: 0.0002 sec.
# ===> Epoch[40](164/521): Loss: 1.0838 || Timer: 0.0002 sec.
# ===> Epoch[40](165/521): Loss: 0.9957 || Timer: 0.0002 sec.
# ===> Epoch[40](166/521): Loss: 0.9574 || Timer: 0.0002 sec.
# ===> Epoch[40](167/521): Loss: 1.1799 || Timer: 0.0002 sec.
# ===> Epoch[40](168/521): Loss: 0.9344 || Timer: 0.0003 sec.
# ===> Epoch[40](169/521): Loss: 0.8689 || Timer: 0.0002 sec.
# ===> Epoch[40](170/521): Loss: 1.3746 || Timer: 0.0002 sec.
# ===> Epoch[40](171/521): Loss: 0.9810 || Timer: 0.0002 sec.
# ===> Epoch[40](172/521): Loss: 0.7853 || Timer: 0.0002 sec.
# ===> Epoch[40](173/521): Loss: 0.9718 || Timer: 0.0002 sec.
# ===> Epoch[40](174/521): Loss: 1.2081 || Timer: 0.0002 sec.
# ===> Epoch[40](175/521): Loss: 1.2188 || Timer: 0.0002 sec.
# ===> Epoch[40](176/521): Loss: 1.0300 || Timer: 0.0002 sec.
# ===> Epoch[40](177/521): Loss: 0.9435 || Timer: 0.0002 sec.
# ===> Epoch[40](178/521): Loss: 1.1089 || Timer: 0.0002 sec.
# ===> Epoch[40](179/521): Loss: 0.9454 || Timer: 0.0002 sec.
# ===> Epoch[40](180/521): Loss: 1.0185 || Timer: 0.0002 sec.
# ===> Epoch[40](181/521): Loss: 1.2625 || Timer: 0.0002 sec.
# ===> Epoch[40](182/521): Loss: 1.1045 || Timer: 0.0002 sec.
# ===> Epoch[40](183/521): Loss: 1.0057 || Timer: 0.0002 sec.
# ===> Epoch[40](184/521): Loss: 0.9597 || Timer: 0.0002 sec.
# ===> Epoch[40](185/521): Loss: 1.0782 || Timer: 0.0002 sec.
# ===> Epoch[40](186/521): Loss: 0.9678 || Timer: 0.0002 sec.
# ===> Epoch[40](187/521): Loss: 1.0396 || Timer: 0.0002 sec.
# ===> Epoch[40](188/521): Loss: 1.0605 || Timer: 0.0002 sec.
# ===> Epoch[40](189/521): Loss: 1.0730 || Timer: 0.0002 sec.
# ===> Epoch[40](190/521): Loss: 0.7970 || Timer: 0.0002 sec.
# ===> Epoch[40](191/521): Loss: 0.9753 || Timer: 0.0002 sec.
# ===> Epoch[40](192/521): Loss: 1.0393 || Timer: 0.0002 sec.
# ===> Epoch[40](193/521): Loss: 1.0693 || Timer: 0.0002 sec.
# ===> Epoch[40](194/521): Loss: 0.8795 || Timer: 0.0002 sec.
# ===> Epoch[40](195/521): Loss: 0.8296 || Timer: 0.0002 sec.
# ===> Epoch[40](196/521): Loss: 1.0300 || Timer: 0.0002 sec.
# ===> Epoch[40](197/521): Loss: 0.9865 || Timer: 0.0002 sec.
# ===> Epoch[40](198/521): Loss: 1.1537 || Timer: 0.0002 sec.
# ===> Epoch[40](199/521): Loss: 0.9326 || Timer: 0.0002 sec.
# ===> Epoch[40](200/521): Loss: 0.9723 || Timer: 0.0002 sec.
# ===> Epoch[40](201/521): Loss: 1.1874 || Timer: 0.0002 sec.
# ===> Epoch[40](202/521): Loss: 0.8549 || Timer: 0.0002 sec.
# ===> Epoch[40](203/521): Loss: 1.0254 || Timer: 0.0002 sec.
# ===> Epoch[40](204/521): Loss: 0.8726 || Timer: 0.0002 sec.
# ===> Epoch[40](205/521): Loss: 1.2792 || Timer: 0.0002 sec.
# ===> Epoch[40](206/521): Loss: 1.0737 || Timer: 0.0002 sec.
# ===> Epoch[40](207/521): Loss: 0.8875 || Timer: 0.0002 sec.
# ===> Epoch[40](208/521): Loss: 1.0738 || Timer: 0.0002 sec.
# ===> Epoch[40](209/521): Loss: 0.9855 || Timer: 0.0002 sec.
# ===> Epoch[40](210/521): Loss: 1.1954 || Timer: 0.0002 sec.
# ===> Epoch[40](211/521): Loss: 0.9612 || Timer: 0.0002 sec.
# ===> Epoch[40](212/521): Loss: 1.1509 || Timer: 0.0002 sec.
# ===> Epoch[40](213/521): Loss: 1.0752 || Timer: 0.0002 sec.
# ===> Epoch[40](214/521): Loss: 0.8543 || Timer: 0.0002 sec.
# ===> Epoch[40](215/521): Loss: 0.9814 || Timer: 0.0003 sec.
# ===> Epoch[40](216/521): Loss: 1.1317 || Timer: 0.0002 sec.
# ===> Epoch[40](217/521): Loss: 0.8228 || Timer: 0.0002 sec.
# ===> Epoch[40](218/521): Loss: 1.0336 || Timer: 0.0002 sec.
# ===> Epoch[40](219/521): Loss: 1.1258 || Timer: 0.0002 sec.
# ===> Epoch[40](220/521): Loss: 1.0881 || Timer: 0.0002 sec.
# ===> Epoch[40](221/521): Loss: 0.9441 || Timer: 0.0003 sec.
# ===> Epoch[40](222/521): Loss: 1.0417 || Timer: 0.0002 sec.
# ===> Epoch[40](223/521): Loss: 1.0882 || Timer: 0.0002 sec.
# ===> Epoch[40](224/521): Loss: 0.9913 || Timer: 0.0002 sec.
# ===> Epoch[40](225/521): Loss: 1.0346 || Timer: 0.0002 sec.
# ===> Epoch[40](226/521): Loss: 0.9119 || Timer: 0.0002 sec.
# ===> Epoch[40](227/521): Loss: 0.9141 || Timer: 0.0002 sec.
# ===> Epoch[40](228/521): Loss: 1.0648 || Timer: 0.0002 sec.
# ===> Epoch[40](229/521): Loss: 0.9177 || Timer: 0.0002 sec.
# ===> Epoch[40](230/521): Loss: 0.9601 || Timer: 0.0002 sec.
# ===> Epoch[40](231/521): Loss: 1.2440 || Timer: 0.0002 sec.
# ===> Epoch[40](232/521): Loss: 1.0862 || Timer: 0.0002 sec.
# ===> Epoch[40](233/521): Loss: 1.1656 || Timer: 0.0002 sec.
# ===> Epoch[40](234/521): Loss: 1.2845 || Timer: 0.0002 sec.
# ===> Epoch[40](235/521): Loss: 0.9983 || Timer: 0.0002 sec.
# ===> Epoch[40](236/521): Loss: 0.8953 || Timer: 0.0002 sec.
# ===> Epoch[40](237/521): Loss: 1.0015 || Timer: 0.0002 sec.
# ===> Epoch[40](238/521): Loss: 0.9020 || Timer: 0.0002 sec.
# ===> Epoch[40](239/521): Loss: 1.1002 || Timer: 0.0002 sec.
# ===> Epoch[40](240/521): Loss: 0.9501 || Timer: 0.0002 sec.
# ===> Epoch[40](241/521): Loss: 1.0981 || Timer: 0.0002 sec.
# ===> Epoch[40](242/521): Loss: 1.2473 || Timer: 0.0002 sec.
# ===> Epoch[40](243/521): Loss: 1.0331 || Timer: 0.0002 sec.
# ===> Epoch[40](244/521): Loss: 1.2961 || Timer: 0.0002 sec.
# ===> Epoch[40](245/521): Loss: 1.0421 || Timer: 0.0002 sec.
# ===> Epoch[40](246/521): Loss: 0.9235 || Timer: 0.0002 sec.
# ===> Epoch[40](247/521): Loss: 0.8060 || Timer: 0.0002 sec.
# ===> Epoch[40](248/521): Loss: 0.6631 || Timer: 0.0002 sec.
# ===> Epoch[40](249/521): Loss: 1.0758 || Timer: 0.0002 sec.
# ===> Epoch[40](250/521): Loss: 0.7525 || Timer: 0.0002 sec.
# ===> Epoch[40](251/521): Loss: 1.2306 || Timer: 0.0002 sec.
# ===> Epoch[40](252/521): Loss: 0.9444 || Timer: 0.0002 sec.
# ===> Epoch[40](253/521): Loss: 1.0682 || Timer: 0.0002 sec.
# ===> Epoch[40](254/521): Loss: 1.1285 || Timer: 0.0002 sec.
# ===> Epoch[40](255/521): Loss: 1.1052 || Timer: 0.0002 sec.
# ===> Epoch[40](256/521): Loss: 1.0515 || Timer: 0.0002 sec.
# ===> Epoch[40](257/521): Loss: 1.0172 || Timer: 0.0002 sec.
# ===> Epoch[40](258/521): Loss: 1.1004 || Timer: 0.0002 sec.
# ===> Epoch[40](259/521): Loss: 1.1600 || Timer: 0.0002 sec.
# ===> Epoch[40](260/521): Loss: 1.0207 || Timer: 0.0002 sec.
# ===> Epoch[40](261/521): Loss: 1.0508 || Timer: 0.0002 sec.
# ===> Epoch[40](262/521): Loss: 1.2680 || Timer: 0.0002 sec.
# ===> Epoch[40](263/521): Loss: 0.8765 || Timer: 0.0002 sec.
# ===> Epoch[40](264/521): Loss: 1.1248 || Timer: 0.0002 sec.
# ===> Epoch[40](265/521): Loss: 0.9061 || Timer: 0.0002 sec.
# ===> Epoch[40](266/521): Loss: 1.0683 || Timer: 0.0002 sec.
# ===> Epoch[40](267/521): Loss: 1.2218 || Timer: 0.0002 sec.
# ===> Epoch[40](268/521): Loss: 1.0640 || Timer: 0.0002 sec.
# ===> Epoch[40](269/521): Loss: 0.7648 || Timer: 0.0002 sec.
# ===> Epoch[40](270/521): Loss: 1.0284 || Timer: 0.0002 sec.
# ===> Epoch[40](271/521): Loss: 0.9985 || Timer: 0.0002 sec.
# ===> Epoch[40](272/521): Loss: 0.8816 || Timer: 0.0002 sec.
# ===> Epoch[40](273/521): Loss: 0.9458 || Timer: 0.0002 sec.
# ===> Epoch[40](274/521): Loss: 1.2408 || Timer: 0.0002 sec.
# ===> Epoch[40](275/521): Loss: 1.0619 || Timer: 0.0002 sec.
# ===> Epoch[40](276/521): Loss: 0.6851 || Timer: 0.0002 sec.
# ===> Epoch[40](277/521): Loss: 1.3539 || Timer: 0.0002 sec.
# ===> Epoch[40](278/521): Loss: 1.1822 || Timer: 0.0002 sec.
# ===> Epoch[40](279/521): Loss: 1.0518 || Timer: 0.0002 sec.
# ===> Epoch[40](280/521): Loss: 1.1404 || Timer: 0.0002 sec.
# ===> Epoch[40](281/521): Loss: 1.2184 || Timer: 0.0002 sec.
# ===> Epoch[40](282/521): Loss: 1.0448 || Timer: 0.0002 sec.
# ===> Epoch[40](283/521): Loss: 0.9548 || Timer: 0.0002 sec.
# ===> Epoch[40](284/521): Loss: 1.0232 || Timer: 0.0002 sec.
# ===> Epoch[40](285/521): Loss: 0.9025 || Timer: 0.0002 sec.
# ===> Epoch[40](286/521): Loss: 1.1317 || Timer: 0.0002 sec.
# ===> Epoch[40](287/521): Loss: 1.1201 || Timer: 0.0002 sec.
# ===> Epoch[40](288/521): Loss: 1.1334 || Timer: 0.0002 sec.
# ===> Epoch[40](289/521): Loss: 0.9522 || Timer: 0.0002 sec.
# ===> Epoch[40](290/521): Loss: 1.2787 || Timer: 0.0002 sec.
# ===> Epoch[40](291/521): Loss: 1.2548 || Timer: 0.0002 sec.
# ===> Epoch[40](292/521): Loss: 0.8539 || Timer: 0.0002 sec.
# ===> Epoch[40](293/521): Loss: 1.1114 || Timer: 0.0002 sec.
# ===> Epoch[40](294/521): Loss: 1.2546 || Timer: 0.0002 sec.
# ===> Epoch[40](295/521): Loss: 0.9898 || Timer: 0.0002 sec.
# ===> Epoch[40](296/521): Loss: 1.1463 || Timer: 0.0002 sec.
# ===> Epoch[40](297/521): Loss: 1.1518 || Timer: 0.0002 sec.
# ===> Epoch[40](298/521): Loss: 1.0154 || Timer: 0.0002 sec.
# ===> Epoch[40](299/521): Loss: 1.1604 || Timer: 0.0002 sec.
# ===> Epoch[40](300/521): Loss: 1.2152 || Timer: 0.0002 sec.
# ===> Epoch[40](301/521): Loss: 1.0581 || Timer: 0.0002 sec.
# ===> Epoch[40](302/521): Loss: 1.3188 || Timer: 0.0002 sec.
# ===> Epoch[40](303/521): Loss: 0.9250 || Timer: 0.0002 sec.
# ===> Epoch[40](304/521): Loss: 1.2728 || Timer: 0.0002 sec.
# ===> Epoch[40](305/521): Loss: 1.4080 || Timer: 0.0002 sec.
# ===> Epoch[40](306/521): Loss: 1.3798 || Timer: 0.0002 sec.
# ===> Epoch[40](307/521): Loss: 1.1829 || Timer: 0.0002 sec.
# ===> Epoch[40](308/521): Loss: 0.9332 || Timer: 0.0002 sec.
# ===> Epoch[40](309/521): Loss: 1.0500 || Timer: 0.0002 sec.
# ===> Epoch[40](310/521): Loss: 1.4117 || Timer: 0.0002 sec.
# ===> Epoch[40](311/521): Loss: 1.2401 || Timer: 0.0002 sec.
# ===> Epoch[40](312/521): Loss: 1.4467 || Timer: 0.0002 sec.
# ===> Epoch[40](313/521): Loss: 0.9554 || Timer: 0.0002 sec.
# ===> Epoch[40](314/521): Loss: 1.0785 || Timer: 0.0002 sec.
# ===> Epoch[40](315/521): Loss: 1.0122 || Timer: 0.0002 sec.
# ===> Epoch[40](316/521): Loss: 0.7995 || Timer: 0.0002 sec.
# ===> Epoch[40](317/521): Loss: 1.1969 || Timer: 0.0002 sec.
# ===> Epoch[40](318/521): Loss: 1.0557 || Timer: 0.0002 sec.
# ===> Epoch[40](319/521): Loss: 1.0293 || Timer: 0.0002 sec.
# ===> Epoch[40](320/521): Loss: 0.9619 || Timer: 0.0002 sec.
# ===> Epoch[40](321/521): Loss: 0.9244 || Timer: 0.0002 sec.
# ===> Epoch[40](322/521): Loss: 1.3389 || Timer: 0.0003 sec.
# ===> Epoch[40](323/521): Loss: 0.9443 || Timer: 0.0002 sec.
# ===> Epoch[40](324/521): Loss: 0.9652 || Timer: 0.0003 sec.
# ===> Epoch[40](325/521): Loss: 1.0113 || Timer: 0.0002 sec.
# ===> Epoch[40](326/521): Loss: 1.0424 || Timer: 0.0002 sec.
# ===> Epoch[40](327/521): Loss: 1.2010 || Timer: 0.0002 sec.
# ===> Epoch[40](328/521): Loss: 1.1654 || Timer: 0.0003 sec.
# ===> Epoch[40](329/521): Loss: 0.7148 || Timer: 0.0003 sec.
# ===> Epoch[40](330/521): Loss: 1.2145 || Timer: 0.0003 sec.
# ===> Epoch[40](331/521): Loss: 1.0257 || Timer: 0.0002 sec.
# ===> Epoch[40](332/521): Loss: 1.1992 || Timer: 0.0003 sec.
# ===> Epoch[40](333/521): Loss: 1.5424 || Timer: 0.0003 sec.
# ===> Epoch[40](334/521): Loss: 1.0599 || Timer: 0.0004 sec.
# ===> Epoch[40](335/521): Loss: 0.9265 || Timer: 0.0002 sec.
# ===> Epoch[40](336/521): Loss: 0.9791 || Timer: 0.0003 sec.
# ===> Epoch[40](337/521): Loss: 1.2565 || Timer: 0.0002 sec.
# ===> Epoch[40](338/521): Loss: 0.9655 || Timer: 0.0002 sec.
# ===> Epoch[40](339/521): Loss: 1.2819 || Timer: 0.0002 sec.
# ===> Epoch[40](340/521): Loss: 1.2312 || Timer: 0.0002 sec.
# ===> Epoch[40](341/521): Loss: 1.0528 || Timer: 0.0002 sec.
# ===> Epoch[40](342/521): Loss: 1.1120 || Timer: 0.0003 sec.
# ===> Epoch[40](343/521): Loss: 1.0643 || Timer: 0.0002 sec.
# ===> Epoch[40](344/521): Loss: 1.2152 || Timer: 0.0002 sec.
# ===> Epoch[40](345/521): Loss: 0.9973 || Timer: 0.0002 sec.
# ===> Epoch[40](346/521): Loss: 1.0498 || Timer: 0.0002 sec.
# ===> Epoch[40](347/521): Loss: 0.9663 || Timer: 0.0002 sec.
# ===> Epoch[40](348/521): Loss: 0.8640 || Timer: 0.0002 sec.
# ===> Epoch[40](349/521): Loss: 1.0477 || Timer: 0.0002 sec.
# ===> Epoch[40](350/521): Loss: 1.0736 || Timer: 0.0002 sec.
# ===> Epoch[40](351/521): Loss: 1.0077 || Timer: 0.0002 sec.
# ===> Epoch[40](352/521): Loss: 1.0820 || Timer: 0.0002 sec.
# ===> Epoch[40](353/521): Loss: 0.9952 || Timer: 0.0002 sec.
# ===> Epoch[40](354/521): Loss: 0.7740 || Timer: 0.0002 sec.
# ===> Epoch[40](355/521): Loss: 1.0484 || Timer: 0.0002 sec.
# ===> Epoch[40](356/521): Loss: 1.1559 || Timer: 0.0002 sec.
# ===> Epoch[40](357/521): Loss: 0.9668 || Timer: 0.0002 sec.
# ===> Epoch[40](358/521): Loss: 0.9279 || Timer: 0.0002 sec.
# ===> Epoch[40](359/521): Loss: 1.1667 || Timer: 0.0002 sec.
# ===> Epoch[40](360/521): Loss: 1.2937 || Timer: 0.0002 sec.
# ===> Epoch[40](361/521): Loss: 1.0872 || Timer: 0.0002 sec.
# ===> Epoch[40](362/521): Loss: 1.0465 || Timer: 0.0009 sec.
# ===> Epoch[40](363/521): Loss: 1.2027 || Timer: 0.0002 sec.
# ===> Epoch[40](364/521): Loss: 1.0174 || Timer: 0.0002 sec.
# ===> Epoch[40](365/521): Loss: 0.9795 || Timer: 0.0002 sec.
# ===> Epoch[40](366/521): Loss: 1.0248 || Timer: 0.0002 sec.
# ===> Epoch[40](367/521): Loss: 1.0658 || Timer: 0.0002 sec.
# ===> Epoch[40](368/521): Loss: 1.1410 || Timer: 0.0002 sec.
# ===> Epoch[40](369/521): Loss: 0.8377 || Timer: 0.0002 sec.
# ===> Epoch[40](370/521): Loss: 1.1974 || Timer: 0.0002 sec.
# ===> Epoch[40](371/521): Loss: 1.0832 || Timer: 0.0002 sec.
# ===> Epoch[40](372/521): Loss: 0.9668 || Timer: 0.0002 sec.
# ===> Epoch[40](373/521): Loss: 0.7838 || Timer: 0.0002 sec.
# ===> Epoch[40](374/521): Loss: 1.0578 || Timer: 0.0003 sec.
# ===> Epoch[40](375/521): Loss: 1.1311 || Timer: 0.0002 sec.
# ===> Epoch[40](376/521): Loss: 0.8243 || Timer: 0.0002 sec.
# ===> Epoch[40](377/521): Loss: 1.2300 || Timer: 0.0002 sec.
# ===> Epoch[40](378/521): Loss: 0.9112 || Timer: 0.0002 sec.
# ===> Epoch[40](379/521): Loss: 1.1440 || Timer: 0.0002 sec.
# ===> Epoch[40](380/521): Loss: 0.9589 || Timer: 0.0002 sec.
# ===> Epoch[40](381/521): Loss: 1.2112 || Timer: 0.0002 sec.
# ===> Epoch[40](382/521): Loss: 0.9690 || Timer: 0.0002 sec.
# ===> Epoch[40](383/521): Loss: 0.9117 || Timer: 0.0002 sec.
# ===> Epoch[40](384/521): Loss: 1.2082 || Timer: 0.0002 sec.
# ===> Epoch[40](385/521): Loss: 1.0179 || Timer: 0.0002 sec.
# ===> Epoch[40](386/521): Loss: 0.9587 || Timer: 0.0002 sec.
# ===> Epoch[40](387/521): Loss: 1.1547 || Timer: 0.0002 sec.
# ===> Epoch[40](388/521): Loss: 0.8771 || Timer: 0.0002 sec.
# ===> Epoch[40](389/521): Loss: 0.9326 || Timer: 0.0002 sec.
# ===> Epoch[40](390/521): Loss: 1.2420 || Timer: 0.0002 sec.
# ===> Epoch[40](391/521): Loss: 1.1272 || Timer: 0.0002 sec.
# ===> Epoch[40](392/521): Loss: 1.2539 || Timer: 0.0002 sec.
# ===> Epoch[40](393/521): Loss: 1.0832 || Timer: 0.0002 sec.
# ===> Epoch[40](394/521): Loss: 1.0673 || Timer: 0.0002 sec.
# ===> Epoch[40](395/521): Loss: 0.9003 || Timer: 0.0002 sec.
# ===> Epoch[40](396/521): Loss: 1.0608 || Timer: 0.0002 sec.
# ===> Epoch[40](397/521): Loss: 1.2072 || Timer: 0.0002 sec.
# ===> Epoch[40](398/521): Loss: 0.7466 || Timer: 0.0003 sec.
# ===> Epoch[40](399/521): Loss: 1.0977 || Timer: 0.0002 sec.
# ===> Epoch[40](400/521): Loss: 1.1891 || Timer: 0.0002 sec.
# ===> Epoch[40](401/521): Loss: 1.0035 || Timer: 0.0003 sec.
# ===> Epoch[40](402/521): Loss: 1.0765 || Timer: 0.0002 sec.
# ===> Epoch[40](403/521): Loss: 1.4141 || Timer: 0.0002 sec.
# ===> Epoch[40](404/521): Loss: 1.0961 || Timer: 0.0002 sec.
# ===> Epoch[40](405/521): Loss: 1.1213 || Timer: 0.0002 sec.
# ===> Epoch[40](406/521): Loss: 1.2464 || Timer: 0.0002 sec.
# ===> Epoch[40](407/521): Loss: 0.9877 || Timer: 0.0002 sec.
# ===> Epoch[40](408/521): Loss: 1.2128 || Timer: 0.0002 sec.
# ===> Epoch[40](409/521): Loss: 0.8467 || Timer: 0.0002 sec.
# ===> Epoch[40](410/521): Loss: 1.0473 || Timer: 0.0002 sec.
# ===> Epoch[40](411/521): Loss: 1.0882 || Timer: 0.0002 sec.
# ===> Epoch[40](412/521): Loss: 1.0877 || Timer: 0.0002 sec.
# ===> Epoch[40](413/521): Loss: 0.9123 || Timer: 0.0002 sec.
# ===> Epoch[40](414/521): Loss: 1.0302 || Timer: 0.0002 sec.
# ===> Epoch[40](415/521): Loss: 1.4457 || Timer: 0.0002 sec.
# ===> Epoch[40](416/521): Loss: 1.2558 || Timer: 0.0002 sec.
# ===> Epoch[40](417/521): Loss: 1.4403 || Timer: 0.0002 sec.
# ===> Epoch[40](418/521): Loss: 1.1633 || Timer: 0.0003 sec.
# ===> Epoch[40](419/521): Loss: 1.2521 || Timer: 0.0002 sec.
# ===> Epoch[40](420/521): Loss: 1.2409 || Timer: 0.0002 sec.
# ===> Epoch[40](421/521): Loss: 1.1644 || Timer: 0.0002 sec.
# ===> Epoch[40](422/521): Loss: 1.2180 || Timer: 0.0002 sec.
# ===> Epoch[40](423/521): Loss: 1.1191 || Timer: 0.0002 sec.
# ===> Epoch[40](424/521): Loss: 1.2236 || Timer: 0.0002 sec.
# ===> Epoch[40](425/521): Loss: 1.2316 || Timer: 0.0002 sec.
# ===> Epoch[40](426/521): Loss: 1.1816 || Timer: 0.0002 sec.
# ===> Epoch[40](427/521): Loss: 1.1092 || Timer: 0.0002 sec.
# ===> Epoch[40](428/521): Loss: 1.1684 || Timer: 0.0002 sec.
# ===> Epoch[40](429/521): Loss: 1.0509 || Timer: 0.0002 sec.
# ===> Epoch[40](430/521): Loss: 1.1299 || Timer: 0.0002 sec.
# ===> Epoch[40](431/521): Loss: 1.3053 || Timer: 0.0002 sec.
# ===> Epoch[40](432/521): Loss: 1.3803 || Timer: 0.0002 sec.
# ===> Epoch[40](433/521): Loss: 1.1770 || Timer: 0.0003 sec.
# ===> Epoch[40](434/521): Loss: 1.1042 || Timer: 0.0002 sec.
# ===> Epoch[40](435/521): Loss: 1.1154 || Timer: 0.0002 sec.
# ===> Epoch[40](436/521): Loss: 0.9338 || Timer: 0.0002 sec.
# ===> Epoch[40](437/521): Loss: 1.1762 || Timer: 0.0002 sec.
# ===> Epoch[40](438/521): Loss: 0.9960 || Timer: 0.0002 sec.
# ===> Epoch[40](439/521): Loss: 1.0457 || Timer: 0.0002 sec.
# ===> Epoch[40](440/521): Loss: 1.1790 || Timer: 0.0002 sec.
# ===> Epoch[40](441/521): Loss: 1.0949 || Timer: 0.0002 sec.
# ===> Epoch[40](442/521): Loss: 0.7761 || Timer: 0.0002 sec.
# ===> Epoch[40](443/521): Loss: 1.0862 || Timer: 0.0002 sec.
# ===> Epoch[40](444/521): Loss: 0.8156 || Timer: 0.0002 sec.
# ===> Epoch[40](445/521): Loss: 1.0491 || Timer: 0.0002 sec.
# ===> Epoch[40](446/521): Loss: 1.2512 || Timer: 0.0002 sec.
# ===> Epoch[40](447/521): Loss: 1.0356 || Timer: 0.0002 sec.
# ===> Epoch[40](448/521): Loss: 1.0344 || Timer: 0.0002 sec.
# ===> Epoch[40](449/521): Loss: 0.9780 || Timer: 0.0002 sec.
# ===> Epoch[40](450/521): Loss: 1.0780 || Timer: 0.0002 sec.
# ===> Epoch[40](451/521): Loss: 1.0044 || Timer: 0.0002 sec.
# ===> Epoch[40](452/521): Loss: 1.3541 || Timer: 0.0003 sec.
# ===> Epoch[40](453/521): Loss: 1.1545 || Timer: 0.0002 sec.
# ===> Epoch[40](454/521): Loss: 0.9481 || Timer: 0.0002 sec.
# ===> Epoch[40](455/521): Loss: 1.0804 || Timer: 0.0002 sec.
# ===> Epoch[40](456/521): Loss: 1.1641 || Timer: 0.0002 sec.
# ===> Epoch[40](457/521): Loss: 1.2242 || Timer: 0.0002 sec.
# ===> Epoch[40](458/521): Loss: 1.1183 || Timer: 0.0002 sec.
# ===> Epoch[40](459/521): Loss: 1.0391 || Timer: 0.0003 sec.
# ===> Epoch[40](460/521): Loss: 1.1178 || Timer: 0.0002 sec.
# ===> Epoch[40](461/521): Loss: 1.3174 || Timer: 0.0002 sec.
# ===> Epoch[40](462/521): Loss: 1.2953 || Timer: 0.0002 sec.
# ===> Epoch[40](463/521): Loss: 0.9480 || Timer: 0.0002 sec.
# ===> Epoch[40](464/521): Loss: 1.1410 || Timer: 0.0003 sec.
# ===> Epoch[40](465/521): Loss: 0.9038 || Timer: 0.0002 sec.
# ===> Epoch[40](466/521): Loss: 1.0206 || Timer: 0.0002 sec.
# ===> Epoch[40](467/521): Loss: 0.8642 || Timer: 0.0002 sec.
# ===> Epoch[40](468/521): Loss: 1.1890 || Timer: 0.0002 sec.
# ===> Epoch[40](469/521): Loss: 1.1456 || Timer: 0.0002 sec.
# ===> Epoch[40](470/521): Loss: 0.9785 || Timer: 0.0003 sec.
# ===> Epoch[40](471/521): Loss: 1.0001 || Timer: 0.0002 sec.
# ===> Epoch[40](472/521): Loss: 0.9629 || Timer: 0.0002 sec.
# ===> Epoch[40](473/521): Loss: 0.8702 || Timer: 0.0002 sec.
# ===> Epoch[40](474/521): Loss: 0.6895 || Timer: 0.0002 sec.
# ===> Epoch[40](475/521): Loss: 1.2758 || Timer: 0.0002 sec.
# ===> Epoch[40](476/521): Loss: 0.9149 || Timer: 0.0002 sec.
# ===> Epoch[40](477/521): Loss: 0.9484 || Timer: 0.0002 sec.
# ===> Epoch[40](478/521): Loss: 1.1458 || Timer: 0.0003 sec.
# ===> Epoch[40](479/521): Loss: 1.1288 || Timer: 0.0002 sec.
# ===> Epoch[40](480/521): Loss: 1.1669 || Timer: 0.0003 sec.
# ===> Epoch[40](481/521): Loss: 0.8471 || Timer: 0.0002 sec.
# ===> Epoch[40](482/521): Loss: 1.1742 || Timer: 0.0002 sec.
# ===> Epoch[40](483/521): Loss: 1.3383 || Timer: 0.0002 sec.
# ===> Epoch[40](484/521): Loss: 1.0438 || Timer: 0.0002 sec.
# ===> Epoch[40](485/521): Loss: 1.1642 || Timer: 0.0002 sec.
# ===> Epoch[40](486/521): Loss: 1.0650 || Timer: 0.0002 sec.
# ===> Epoch[40](487/521): Loss: 1.0363 || Timer: 0.0002 sec.
# ===> Epoch[40](488/521): Loss: 0.9810 || Timer: 0.0002 sec.
# ===> Epoch[40](489/521): Loss: 1.2467 || Timer: 0.0002 sec.
# ===> Epoch[40](490/521): Loss: 1.1520 || Timer: 0.0002 sec.
# ===> Epoch[40](491/521): Loss: 1.1115 || Timer: 0.0002 sec.
# ===> Epoch[40](492/521): Loss: 1.1498 || Timer: 0.0002 sec.
# ===> Epoch[40](493/521): Loss: 1.0004 || Timer: 0.0003 sec.
# ===> Epoch[40](494/521): Loss: 1.0800 || Timer: 0.0002 sec.
# ===> Epoch[40](495/521): Loss: 1.1847 || Timer: 0.0002 sec.
# ===> Epoch[40](496/521): Loss: 1.1163 || Timer: 0.0002 sec.
# ...
# ===> Epoch[48](432/521): Loss: 0.8864 || Timer: 0.0002 sec.
# ===> Epoch[48](433/521): Loss: 1.0461 || Timer: 0.0002 sec.
# ===> Epoch[48](434/521): Loss: 0.8435 || Timer: 0.0002 sec.
# ===> Epoch[48](435/521): Loss: 1.0202 || Timer: 0.0002 sec.
# ===> Epoch[48](436/521): Loss: 0.9377 || Timer: 0.0002 sec.
# ===> Epoch[48](437/521): Loss: 0.9111 || Timer: 0.0002 sec.
# ===> Epoch[48](438/521): Loss: 1.0409 || Timer: 0.0002 sec.
# ===> Epoch[48](439/521): Loss: 0.9799 || Timer: 0.0002 sec.
# ===> Epoch[48](440/521): Loss: 0.9281 || Timer: 0.0002 sec.
# ===> Epoch[48](441/521): Loss: 0.8691 || Timer: 0.0002 sec.
# ===> Epoch[48](442/521): Loss: 0.9650 || Timer: 0.0002 sec.
# ===> Epoch[48](443/521): Loss: 1.2677 || Timer: 0.0002 sec.
# ===> Epoch[48](444/521): Loss: 1.1658 || Timer: 0.0002 sec.
# ===> Epoch[48](445/521): Loss: 1.1052 || Timer: 0.0002 sec.
# ===> Epoch[48](446/521): Loss: 1.1194 || Timer: 0.0002 sec.
# ===> Epoch[48](447/521): Loss: 1.0526 || Timer: 0.0002 sec.
# ===> Epoch[48](448/521): Loss: 0.9810 || Timer: 0.0002 sec.
# ===> Epoch[48](449/521): Loss: 1.0141 || Timer: 0.0003 sec.
# ===> Epoch[48](450/521): Loss: 1.0042 || Timer: 0.0002 sec.
# ===> Epoch[48](451/521): Loss: 1.0858 || Timer: 0.0002 sec.
# ===> Epoch[48](452/521): Loss: 1.1378 || Timer: 0.0002 sec.
# ===> Epoch[48](453/521): Loss: 1.0132 || Timer: 0.0002 sec.
# ===> Epoch[48](454/521): Loss: 0.8011 || Timer: 0.0003 sec.
# ===> Epoch[48](455/521): Loss: 1.2251 || Timer: 0.0002 sec.
# ===> Epoch[48](456/521): Loss: 0.9882 || Timer: 0.0002 sec.
# ===> Epoch[48](457/521): Loss: 0.9852 || Timer: 0.0002 sec.
# ===> Epoch[48](458/521): Loss: 1.1710 || Timer: 0.0008 sec.
# ===> Epoch[48](459/521): Loss: 0.9910 || Timer: 0.0002 sec.
# ===> Epoch[48](460/521): Loss: 0.9137 || Timer: 0.0002 sec.
# ===> Epoch[48](461/521): Loss: 1.0723 || Timer: 0.0002 sec.
# ===> Epoch[48](462/521): Loss: 1.1500 || Timer: 0.0002 sec.
# ===> Epoch[48](463/521): Loss: 0.9321 || Timer: 0.0002 sec.
# ===> Epoch[48](464/521): Loss: 0.9219 || Timer: 0.0002 sec.
# ===> Epoch[48](465/521): Loss: 0.9374 || Timer: 0.0002 sec.
# ===> Epoch[48](466/521): Loss: 1.1414 || Timer: 0.0002 sec.
# ===> Epoch[48](467/521): Loss: 0.8819 || Timer: 0.0002 sec.
# ===> Epoch[48](468/521): Loss: 1.2697 || Timer: 0.0002 sec.
# ===> Epoch[48](469/521): Loss: 1.1055 || Timer: 0.0002 sec.
# ===> Epoch[48](470/521): Loss: 1.1801 || Timer: 0.0002 sec.
# ===> Epoch[48](471/521): Loss: 1.0187 || Timer: 0.0002 sec.
# ===> Epoch[48](472/521): Loss: 0.9553 || Timer: 0.0002 sec.
# ===> Epoch[48](473/521): Loss: 0.9356 || Timer: 0.0002 sec.
# ===> Epoch[48](474/521): Loss: 0.9938 || Timer: 0.0002 sec.
# ===> Epoch[48](475/521): Loss: 1.0080 || Timer: 0.0002 sec.
# ===> Epoch[48](476/521): Loss: 1.1397 || Timer: 0.0002 sec.
# ===> Epoch[48](477/521): Loss: 0.9860 || Timer: 0.0002 sec.
# ===> Epoch[48](478/521): Loss: 1.0612 || Timer: 0.0002 sec.
# ===> Epoch[48](479/521): Loss: 1.0933 || Timer: 0.0002 sec.
# ===> Epoch[48](480/521): Loss: 1.1271 || Timer: 0.0002 sec.
# ===> Epoch[48](481/521): Loss: 1.0674 || Timer: 0.0002 sec.
# ===> Epoch[48](482/521): Loss: 1.1586 || Timer: 0.0002 sec.
# ===> Epoch[48](483/521): Loss: 1.0983 || Timer: 0.0002 sec.
# ===> Epoch[48](484/521): Loss: 1.1862 || Timer: 0.0002 sec.
# ===> Epoch[48](485/521): Loss: 1.2475 || Timer: 0.0002 sec.
# ===> Epoch[48](486/521): Loss: 1.0220 || Timer: 0.0002 sec.
# ===> Epoch[48](487/521): Loss: 1.2105 || Timer: 0.0002 sec.
# ===> Epoch[48](488/521): Loss: 0.9881 || Timer: 0.0002 sec.
# ===> Epoch[48](489/521): Loss: 1.0700 || Timer: 0.0002 sec.
# ===> Epoch[48](490/521): Loss: 0.9709 || Timer: 0.0002 sec.
# ===> Epoch[48](491/521): Loss: 1.0794 || Timer: 0.0002 sec.
# ===> Epoch[48](492/521): Loss: 1.1847 || Timer: 0.0002 sec.
# ===> Epoch[48](493/521): Loss: 1.2086 || Timer: 0.0002 sec.
# ===> Epoch[48](494/521): Loss: 0.9111 || Timer: 0.0002 sec.
# ===> Epoch[48](495/521): Loss: 1.0310 || Timer: 0.0002 sec.
# ===> Epoch[48](496/521): Loss: 1.2849 || Timer: 0.0002 sec.
# ===> Epoch[48](497/521): Loss: 1.0046 || Timer: 0.0002 sec.
# ===> Epoch[48](498/521): Loss: 0.8593 || Timer: 0.0002 sec.
# ===> Epoch[48](499/521): Loss: 1.1376 || Timer: 0.0002 sec.
# ===> Epoch[48](500/521): Loss: 1.3285 || Timer: 0.0002 sec.
# ===> Epoch[48](501/521): Loss: 0.9945 || Timer: 0.0002 sec.
# ===> Epoch[48](502/521): Loss: 1.1031 || Timer: 0.0002 sec.
# ===> Epoch[48](503/521): Loss: 0.8036 || Timer: 0.0002 sec.
# ===> Epoch[48](504/521): Loss: 0.8968 || Timer: 0.0002 sec.
# ===> Epoch[48](505/521): Loss: 1.0471 || Timer: 0.0002 sec.
# ===> Epoch[48](506/521): Loss: 1.0344 || Timer: 0.0002 sec.
# ===> Epoch[48](507/521): Loss: 1.2256 || Timer: 0.0002 sec.
# ===> Epoch[48](508/521): Loss: 1.1159 || Timer: 0.0002 sec.
# ===> Epoch[48](509/521): Loss: 0.9400 || Timer: 0.0002 sec.
# ===> Epoch[48](510/521): Loss: 1.0770 || Timer: 0.0002 sec.
# ===> Epoch[48](511/521): Loss: 0.9850 || Timer: 0.0002 sec.
# ===> Epoch[48](512/521): Loss: 0.9198 || Timer: 0.0003 sec.
# ===> Epoch[48](513/521): Loss: 0.7007 || Timer: 0.0002 sec.
# ===> Epoch[48](514/521): Loss: 1.1557 || Timer: 0.0002 sec.
# ===> Epoch[48](515/521): Loss: 0.9703 || Timer: 0.0002 sec.
# ===> Epoch[48](516/521): Loss: 1.2784 || Timer: 0.0002 sec.
# ===> Epoch[48](517/521): Loss: 1.1049 || Timer: 0.0002 sec.
# ===> Epoch[48](518/521): Loss: 1.1470 || Timer: 0.0002 sec.
# ===> Epoch[48](519/521): Loss: 1.1393 || Timer: 0.0002 sec.
# ===> Epoch[48](520/521): Loss: 1.0483 || Timer: 0.0002 sec.
# ===> Epoch 48 Complete: Avg. Loss: 1.0667 | Time: 0.3919
# [Epoch 48] Best accuracy: 0.6057
# ===> Epoch[49](0/521): Loss: 0.8869 || Timer: 0.0002 sec.
# ===> Epoch[49](1/521): Loss: 0.9594 || Timer: 0.0002 sec.
# ===> Epoch[49](2/521): Loss: 0.9489 || Timer: 0.0002 sec.
# ===> Epoch[49](3/521): Loss: 0.8602 || Timer: 0.0002 sec.
# ===> Epoch[49](4/521): Loss: 0.9273 || Timer: 0.0002 sec.
# ===> Epoch[49](5/521): Loss: 1.0632 || Timer: 0.0002 sec.
# ===> Epoch[49](6/521): Loss: 0.7882 || Timer: 0.0002 sec.
# ===> Epoch[49](7/521): Loss: 1.0419 || Timer: 0.0002 sec.
# ===> Epoch[49](8/521): Loss: 1.0032 || Timer: 0.0002 sec.
# ===> Epoch[49](9/521): Loss: 0.9836 || Timer: 0.0002 sec.
# ===> Epoch[49](10/521): Loss: 0.9415 || Timer: 0.0002 sec.
# ===> Epoch[49](11/521): Loss: 0.8760 || Timer: 0.0002 sec.
# ===> Epoch[49](12/521): Loss: 0.9365 || Timer: 0.0002 sec.
# ===> Epoch[49](13/521): Loss: 0.9152 || Timer: 0.0002 sec.
# ===> Epoch[49](14/521): Loss: 0.9687 || Timer: 0.0002 sec.
# ===> Epoch[49](15/521): Loss: 0.7643 || Timer: 0.0002 sec.
# ===> Epoch[49](16/521): Loss: 1.0256 || Timer: 0.0002 sec.
# ===> Epoch[49](17/521): Loss: 1.0148 || Timer: 0.0002 sec.
# ===> Epoch[49](18/521): Loss: 1.0203 || Timer: 0.0002 sec.
# ===> Epoch[49](19/521): Loss: 0.8725 || Timer: 0.0002 sec.
# ===> Epoch[49](20/521): Loss: 0.9250 || Timer: 0.0002 sec.
# ===> Epoch[49](21/521): Loss: 1.0882 || Timer: 0.0002 sec.
# ===> Epoch[49](22/521): Loss: 0.9423 || Timer: 0.0002 sec.
# ===> Epoch[49](23/521): Loss: 0.6774 || Timer: 0.0002 sec.
# ===> Epoch[49](24/521): Loss: 0.7115 || Timer: 0.0002 sec.
# ===> Epoch[49](25/521): Loss: 0.8054 || Timer: 0.0002 sec.
# ===> Epoch[49](26/521): Loss: 0.8547 || Timer: 0.0002 sec.
# ===> Epoch[49](27/521): Loss: 0.8765 || Timer: 0.0003 sec.
# ===> Epoch[49](28/521): Loss: 0.8278 || Timer: 0.0002 sec.
# ===> Epoch[49](29/521): Loss: 1.0282 || Timer: 0.0003 sec.
# ===> Epoch[49](30/521): Loss: 0.9193 || Timer: 0.0002 sec.
# ===> Epoch[49](31/521): Loss: 0.6568 || Timer: 0.0003 sec.
# ===> Epoch[49](32/521): Loss: 0.8610 || Timer: 0.0002 sec.
# ===> Epoch[49](33/521): Loss: 0.9264 || Timer: 0.0002 sec.
# ===> Epoch[49](34/521): Loss: 0.8803 || Timer: 0.0002 sec.
# ===> Epoch[49](35/521): Loss: 0.7147 || Timer: 0.0002 sec.
# ===> Epoch[49](36/521): Loss: 0.7762 || Timer: 0.0003 sec.
# ===> Epoch[49](37/521): Loss: 0.9361 || Timer: 0.0002 sec.
# ===> Epoch[49](38/521): Loss: 0.8762 || Timer: 0.0002 sec.
# ===> Epoch[49](39/521): Loss: 1.1672 || Timer: 0.0002 sec.
# ===> Epoch[49](40/521): Loss: 1.0518 || Timer: 0.0002 sec.
# ===> Epoch[49](41/521): Loss: 1.0532 || Timer: 0.0002 sec.
# ===> Epoch[49](42/521): Loss: 1.0044 || Timer: 0.0002 sec.
# ===> Epoch[49](43/521): Loss: 0.9201 || Timer: 0.0001 sec.
# ===> Epoch[49](44/521): Loss: 0.8099 || Timer: 0.0002 sec.
# ===> Epoch[49](45/521): Loss: 0.8964 || Timer: 0.0002 sec.
# ===> Epoch[49](46/521): Loss: 0.8504 || Timer: 0.0002 sec.
# ===> Epoch[49](47/521): Loss: 0.9219 || Timer: 0.0002 sec.
# ===> Epoch[49](48/521): Loss: 1.1461 || Timer: 0.0002 sec.
# ===> Epoch[49](49/521): Loss: 1.0635 || Timer: 0.0002 sec.
# ===> Epoch[49](50/521): Loss: 0.8161 || Timer: 0.0002 sec.
# ===> Epoch[49](51/521): Loss: 0.9344 || Timer: 0.0002 sec.
# ===> Epoch[49](52/521): Loss: 0.9272 || Timer: 0.0002 sec.
# ===> Epoch[49](53/521): Loss: 1.1598 || Timer: 0.0002 sec.
# ===> Epoch[49](54/521): Loss: 1.1366 || Timer: 0.0002 sec.
# ===> Epoch[49](55/521): Loss: 0.7391 || Timer: 0.0002 sec.
# ===> Epoch[49](56/521): Loss: 0.9422 || Timer: 0.0002 sec.
# ===> Epoch[49](57/521): Loss: 0.6913 || Timer: 0.0002 sec.
# ===> Epoch[49](58/521): Loss: 0.8119 || Timer: 0.0002 sec.
# ===> Epoch[49](59/521): Loss: 0.7761 || Timer: 0.0002 sec.
# ===> Epoch[49](60/521): Loss: 1.1645 || Timer: 0.0002 sec.
# ===> Epoch[49](61/521): Loss: 1.0470 || Timer: 0.0002 sec.
# ===> Epoch[49](62/521): Loss: 0.9546 || Timer: 0.0002 sec.
# ===> Epoch[49](63/521): Loss: 0.8610 || Timer: 0.0002 sec.
# ===> Epoch[49](64/521): Loss: 0.9947 || Timer: 0.0002 sec.
# ===> Epoch[49](65/521): Loss: 1.0259 || Timer: 0.0002 sec.
# ===> Epoch[49](66/521): Loss: 1.0291 || Timer: 0.0002 sec.
# ===> Epoch[49](67/521): Loss: 0.7282 || Timer: 0.0002 sec.
# ===> Epoch[49](68/521): Loss: 0.8600 || Timer: 0.0002 sec.
# ===> Epoch[49](69/521): Loss: 0.9319 || Timer: 0.0002 sec.
# ===> Epoch[49](70/521): Loss: 1.1967 || Timer: 0.0002 sec.
# ===> Epoch[49](71/521): Loss: 1.2449 || Timer: 0.0002 sec.
# ===> Epoch[49](72/521): Loss: 0.9365 || Timer: 0.0002 sec.
# ===> Epoch[49](73/521): Loss: 0.7655 || Timer: 0.0002 sec.
# ===> Epoch[49](74/521): Loss: 1.0074 || Timer: 0.0002 sec.
# ===> Epoch[49](75/521): Loss: 0.8721 || Timer: 0.0002 sec.
# ===> Epoch[49](76/521): Loss: 1.0856 || Timer: 0.0002 sec.
# ===> Epoch[49](77/521): Loss: 0.8229 || Timer: 0.0002 sec.
# ===> Epoch[49](78/521): Loss: 1.0079 || Timer: 0.0001 sec.
# ===> Epoch[49](79/521): Loss: 0.8061 || Timer: 0.0002 sec.
# ===> Epoch[49](80/521): Loss: 0.9411 || Timer: 0.0002 sec.
# ===> Epoch[49](81/521): Loss: 0.8341 || Timer: 0.0002 sec.
# ===> Epoch[49](82/521): Loss: 0.8954 || Timer: 0.0002 sec.
# ===> Epoch[49](83/521): Loss: 0.8980 || Timer: 0.0002 sec.
# ===> Epoch[49](84/521): Loss: 0.9922 || Timer: 0.0002 sec.
# ===> Epoch[49](85/521): Loss: 0.8444 || Timer: 0.0002 sec.
# ===> Epoch[49](86/521): Loss: 1.0417 || Timer: 0.0002 sec.
# ===> Epoch[49](87/521): Loss: 0.9368 || Timer: 0.0002 sec.
# ===> Epoch[49](88/521): Loss: 0.7884 || Timer: 0.0002 sec.
# ===> Epoch[49](89/521): Loss: 0.7482 || Timer: 0.0002 sec.
# ===> Epoch[49](90/521): Loss: 1.0167 || Timer: 0.0002 sec.
# ===> Epoch[49](91/521): Loss: 1.0351 || Timer: 0.0002 sec.
# ===> Epoch[49](92/521): Loss: 0.8826 || Timer: 0.0001 sec.
# ===> Epoch[49](93/521): Loss: 0.8911 || Timer: 0.0001 sec.
# ===> Epoch[49](94/521): Loss: 0.9961 || Timer: 0.0002 sec.
# ===> Epoch[49](95/521): Loss: 1.1448 || Timer: 0.0001 sec.
# ===> Epoch[49](96/521): Loss: 0.8153 || Timer: 0.0002 sec.
# ===> Epoch[49](97/521): Loss: 0.9483 || Timer: 0.0002 sec.
# ===> Epoch[49](98/521): Loss: 1.0976 || Timer: 0.0002 sec.
# ===> Epoch[49](99/521): Loss: 1.2188 || Timer: 0.0003 sec.
# ===> Epoch[49](100/521): Loss: 1.1884 || Timer: 0.0002 sec.
# ===> Epoch[49](101/521): Loss: 0.8517 || Timer: 0.0002 sec.
# ===> Epoch[49](102/521): Loss: 0.8235 || Timer: 0.0002 sec.
# ===> Epoch[49](103/521): Loss: 0.8475 || Timer: 0.0002 sec.
# ===> Epoch[49](104/521): Loss: 0.8932 || Timer: 0.0002 sec.
# ===> Epoch[49](105/521): Loss: 0.8205 || Timer: 0.0002 sec.
# ===> Epoch[49](106/521): Loss: 1.0062 || Timer: 0.0002 sec.
# ===> Epoch[49](107/521): Loss: 1.2276 || Timer: 0.0002 sec.
# ===> Epoch[49](108/521): Loss: 0.8467 || Timer: 0.0002 sec.
# ===> Epoch[49](109/521): Loss: 1.0684 || Timer: 0.0002 sec.
# ===> Epoch[49](110/521): Loss: 0.7817 || Timer: 0.0002 sec.
# ===> Epoch[49](111/521): Loss: 0.9152 || Timer: 0.0002 sec.
# ===> Epoch[49](112/521): Loss: 1.0624 || Timer: 0.0002 sec.
# ===> Epoch[49](113/521): Loss: 1.0866 || Timer: 0.0002 sec.
# ===> Epoch[49](114/521): Loss: 1.0537 || Timer: 0.0003 sec.
# ===> Epoch[49](115/521): Loss: 1.0321 || Timer: 0.0002 sec.
# ===> Epoch[49](116/521): Loss: 0.9467 || Timer: 0.0003 sec.
# ===> Epoch[49](117/521): Loss: 1.1515 || Timer: 0.0002 sec.
# ===> Epoch[49](118/521): Loss: 0.9175 || Timer: 0.0003 sec.
# ===> Epoch[49](119/521): Loss: 1.0511 || Timer: 0.0002 sec.
# ===> Epoch[49](120/521): Loss: 0.8275 || Timer: 0.0002 sec.
# ===> Epoch[49](121/521): Loss: 0.8622 || Timer: 0.0002 sec.
# ===> Epoch[49](122/521): Loss: 1.0195 || Timer: 0.0002 sec.
# ===> Epoch[49](123/521): Loss: 0.9512 || Timer: 0.0002 sec.
# ===> Epoch[49](124/521): Loss: 0.8019 || Timer: 0.0002 sec.
# ===> Epoch[49](125/521): Loss: 1.0095 || Timer: 0.0002 sec.
# ===> Epoch[49](126/521): Loss: 0.9477 || Timer: 0.0002 sec.
# ===> Epoch[49](127/521): Loss: 0.8632 || Timer: 0.0002 sec.
# ===> Epoch[49](128/521): Loss: 1.1673 || Timer: 0.0002 sec.
# ===> Epoch[49](129/521): Loss: 1.1363 || Timer: 0.0002 sec.
# ===> Epoch[49](130/521): Loss: 0.7524 || Timer: 0.0002 sec.
# ===> Epoch[49](131/521): Loss: 0.9202 || Timer: 0.0002 sec.
# ===> Epoch[49](132/521): Loss: 0.8215 || Timer: 0.0002 sec.
# ===> Epoch[49](133/521): Loss: 1.1788 || Timer: 0.0002 sec.
# ===> Epoch[49](134/521): Loss: 1.0260 || Timer: 0.0002 sec.
# ===> Epoch[49](135/521): Loss: 0.8843 || Timer: 0.0002 sec.
# ===> Epoch[49](136/521): Loss: 0.9655 || Timer: 0.0002 sec.
# ===> Epoch[49](137/521): Loss: 1.2399 || Timer: 0.0002 sec.
# ===> Epoch[49](138/521): Loss: 0.9033 || Timer: 0.0002 sec.
# ===> Epoch[49](139/521): Loss: 1.0773 || Timer: 0.0002 sec.
# ===> Epoch[49](140/521): Loss: 0.9812 || Timer: 0.0002 sec.
# ===> Epoch[49](141/521): Loss: 1.0474 || Timer: 0.0002 sec.
# ===> Epoch[49](142/521): Loss: 0.8391 || Timer: 0.0002 sec.
# ===> Epoch[49](143/521): Loss: 0.9116 || Timer: 0.0002 sec.
# ===> Epoch[49](144/521): Loss: 0.8788 || Timer: 0.0003 sec.
# ===> Epoch[49](145/521): Loss: 0.7162 || Timer: 0.0002 sec.
# ===> Epoch[49](146/521): Loss: 1.0966 || Timer: 0.0002 sec.
# ===> Epoch[49](147/521): Loss: 0.9760 || Timer: 0.0002 sec.
# ===> Epoch[49](148/521): Loss: 1.1289 || Timer: 0.0002 sec.
# ===> Epoch[49](149/521): Loss: 1.0972 || Timer: 0.0002 sec.
# ===> Epoch[49](150/521): Loss: 0.9040 || Timer: 0.0002 sec.
# ===> Epoch[49](151/521): Loss: 1.2780 || Timer: 0.0003 sec.
# ===> Epoch[49](152/521): Loss: 0.9940 || Timer: 0.0002 sec.
# ===> Epoch[49](153/521): Loss: 1.1334 || Timer: 0.0003 sec.
# ===> Epoch[49](154/521): Loss: 0.7991 || Timer: 0.0002 sec.
# ===> Epoch[49](155/521): Loss: 1.1486 || Timer: 0.0002 sec.
# ===> Epoch[49](156/521): Loss: 1.0954 || Timer: 0.0002 sec.
# ===> Epoch[49](157/521): Loss: 0.9272 || Timer: 0.0002 sec.
# ===> Epoch[49](158/521): Loss: 0.9738 || Timer: 0.0002 sec.
# ===> Epoch[49](159/521): Loss: 0.9554 || Timer: 0.0002 sec.
# ===> Epoch[49](160/521): Loss: 1.1242 || Timer: 0.0002 sec.
# ===> Epoch[49](161/521): Loss: 1.0499 || Timer: 0.0002 sec.
# ===> Epoch[49](162/521): Loss: 1.0622 || Timer: 0.0002 sec.
# ===> Epoch[49](163/521): Loss: 1.0183 || Timer: 0.0002 sec.
# ===> Epoch[49](164/521): Loss: 0.9651 || Timer: 0.0002 sec.
# ===> Epoch[49](165/521): Loss: 1.1812 || Timer: 0.0002 sec.
# ===> Epoch[49](166/521): Loss: 1.2057 || Timer: 0.0002 sec.
# ===> Epoch[49](167/521): Loss: 1.0369 || Timer: 0.0002 sec.
# ===> Epoch[49](168/521): Loss: 0.9582 || Timer: 0.0002 sec.
# ===> Epoch[49](169/521): Loss: 1.1088 || Timer: 0.0002 sec.
# ===> Epoch[49](170/521): Loss: 1.4735 || Timer: 0.0002 sec.
# ===> Epoch[49](171/521): Loss: 1.2961 || Timer: 0.0002 sec.
# ===> Epoch[49](172/521): Loss: 1.0599 || Timer: 0.0002 sec.
# ===> Epoch[49](173/521): Loss: 1.0252 || Timer: 0.0002 sec.
# ===> Epoch[49](174/521): Loss: 0.7933 || Timer: 0.0002 sec.
# ===> Epoch[49](175/521): Loss: 1.3166 || Timer: 0.0002 sec.
# ===> Epoch[49](176/521): Loss: 1.1154 || Timer: 0.0002 sec.
# ===> Epoch[49](177/521): Loss: 0.9945 || Timer: 0.0002 sec.
